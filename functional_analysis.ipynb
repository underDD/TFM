# %% [markdown]
# # 2D

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from scipy.signal import find_peaks
from pypalettes import load_cmap
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import functions_create_networks as fcn

from matplotlib.ticker import FuncFormatter

def k_formatter(x, pos):
    if x == 0:
        return "0"
    if abs(x) >= 1000:
        val = x / 1000
        return f"{val:g}k"
    return f"{x:g}"

def make_grid(filename, value):
    df = pd.read_csv(filename, sep="\t")

    pivot = df.pivot(
        index="MAX_EXC_WEIGHT",
        columns="Gini",
        values=value
    ).sort_index()

    x = pivot.columns.to_numpy(dtype=float)
    y = pivot.index.to_numpy(dtype=float)
    Z = pivot.to_numpy(dtype=float)

    return x, y, Z

def load_raster_gna(filename_dyn, sim_time=10000, W=25):

    firings_t, firings_i = fcn.load_firings(filename_dyn)

    N = int(np.max(firings_i))

    GNA = fcn.compute_GNA_from_raster(
        firings_t=firings_t,
        firings_i=firings_i,
        N=N,
        SIM_TIME=sim_time,
        W=W
    )

    prom = 0.2 * np.std(GNA)

    peaks, properties = find_peaks(
        GNA,
        prominence=prom,
        height=0.08,
        distance=20
    )

    return firings_t, firings_i, GNA, peaks, N

def plot_activity_map_ax(
    ax,
    filename,
    panel_label,
    heatmap_value="fano_factor",
    contour_value="mean_peaks_height",
    smooth_sigma=1.5,
    contour_levels=[0.2, 0.9],
    cmap="viridis",
    vmin=None,
    vmax=None
):

    x, y, Z_heat = make_grid(filename, heatmap_value)
    _, _, Z_contour = make_grid(filename, contour_value)

    Z_contour_smooth = gaussian_filter(Z_contour, sigma=smooth_sigma)

    im = ax.imshow(
        Z_heat,
        origin="lower",
        aspect="auto",
        extent=[x.min(), x.max(), y.min(), y.max()],
        cmap=cmap,
        vmin=vmin,
        vmax=vmax,
        interpolation="nearest"
    )

    ax.set_box_aspect(1)   # mapa cuadrado

    cs = ax.contour(
        x,
        y,
        Z_contour_smooth,
        levels=contour_levels,
        colors="white",
        linewidths=1.4
    )

    ax.clabel(
        cs,
        inline=True,
        fontsize=11,
        fmt="%.2f"
    )

    ax.text(
        0.03, 1.1,
        panel_label,
        transform=ax.transAxes,
        ha="left",
        va="top",
        fontsize=17,
        color="black",
        bbox=dict(
            facecolor="white",
            edgecolor="none",
            alpha=0.8,
            pad=3
        )
    )

    ax.set_xlabel(r"$\Lambda$", fontsize=17)
    ax.set_ylabel(r"$E$", fontsize=17)
    ax.tick_params(axis="both", labelsize=12)

    return im

def plot_raster_gna_ax(
    axR,
    axG,
    filename_dyn,
    panel_label,
    info_label,
    sim_time=10000,
    color=None
):

    firings_t, firings_i, GNA, peaks, N = load_raster_gna(
        filename_dyn,
        sim_time=sim_time
    )

    axR.scatter(
        firings_t,
        firings_i - 1,
        s=0.12,
        color=color,
        rasterized=True
    )

    axR.text(
        0.03, 0.95,
        panel_label,
        transform=axR.transAxes,
        ha="left",
        va="top",
        fontsize=14,
        fontweight="bold",
        color="black"
    )

    axR.text(
        0.97, 0.95,
        info_label,
        transform=axR.transAxes,
        ha="right",
        va="top",
        fontsize=10,
        color="black",
        bbox=dict(
            facecolor="white",
            edgecolor="black",
            linewidth=0.6,
            alpha=0.85,
            pad=3
        )
    )

    axR.set_ylabel("Neuron", fontsize=11)
    axR.set_ylim(N - 0.5, -0.5)
    axR.set_xlim(0, sim_time)
    axR.tick_params(axis="x", labelbottom=False)
    axR.tick_params(axis="both", labelsize=9)

    time = np.arange(1, sim_time + 1)

    axG.plot(
        time,
        GNA,
        lw=1.1,
        color=color
    )

    # axG.scatter(
    #     peaks + 1,
    #     GNA[peaks],
    #     s=8,
    #     color="red",
    #     zorder=3
    # )

    axG.set_xlabel("Time (ms)", fontsize=11)
    axG.set_ylabel("GNA", fontsize=11)
    axG.set_xlim(0, sim_time)
    axG.tick_params(axis="both", labelsize=9)

def plot_maps_and_rasters_panel(
    map_file_2D,
    map_file_3D,
    dyn_files,
    raster_info,
    map_labels=("A) 2D", "B) 3D"),
    raster_labels=("C)", "D)", "E)", "F)"),
    sim_time=10000,
    heatmap_value="fano_factor",
    contour_value="mean_peaks_height",
    smooth_sigma=1.5,
    contour_levels=[0.2, 0.9],
    cmap="viridis",
    figsize=(18, 5.5)
):

    sunset2 = load_cmap("Sunset2", cmap_type="continuous")
    raster_color = sunset2(0.1)

    _, _, Z_2D = make_grid(map_file_2D, heatmap_value)
    _, _, Z_3D = make_grid(map_file_3D, heatmap_value)

    vmin = min(np.nanmin(Z_2D), np.nanmin(Z_3D))
    vmax = max(np.nanmax(Z_2D), np.nanmax(Z_3D))

    fig = plt.figure(figsize=figsize)

    # Columna 2 = espacio vacío entre colorbar y rasters
    gs = fig.add_gridspec(
        2, 5,
        width_ratios=[1.25, 1.25, 0.18, 0.85, 0.85],
        height_ratios=[1, 1],
        wspace=0.24,
        hspace=0.28
    )

    # =========================
    # MAPS
    # =========================

    axM2D = fig.add_subplot(gs[:, 0])
    axM3D = fig.add_subplot(gs[:, 1], sharey=axM2D)

    im = plot_activity_map_ax(
        axM2D,
        map_file_2D,
        map_labels[0],
        heatmap_value=heatmap_value,
        contour_value=contour_value,
        smooth_sigma=smooth_sigma,
        contour_levels=contour_levels,
        cmap=cmap,
        vmin=vmin,
        vmax=vmax
    )

    im = plot_activity_map_ax(
        axM3D,
        map_file_3D,
        map_labels[1],
        heatmap_value=heatmap_value,
        contour_value=contour_value,
        smooth_sigma=smooth_sigma,
        contour_levels=contour_levels,
        cmap=cmap,
        vmin=vmin,
        vmax=vmax
    )

    axM3D.set_ylabel("")
    axM3D.tick_params(axis="y", labelleft=False)

    cax = inset_axes(
        axM3D,
        width="4%",
        height="100%",
        loc="lower left",
        bbox_to_anchor=(1.06, 0.0, 1, 1),
        bbox_transform=axM3D.transAxes,
        borderpad=0
    )

    cbar = fig.colorbar(im, cax=cax)
    cbar.ax.set_title(r"$F=\sigma^2/\mu$", fontsize=15, pad=10)
    cbar.ax.tick_params(labelsize=11)

    # =========================
    # RASTERS
    # =========================

    raster_axes = []
    gna_axes = []

    positions = [
        (0, 3),
        (0, 4),
        (1, 3),
        (1, 4),
    ]

    for k, (row, col) in enumerate(positions):

        sub = gs[row, col].subgridspec(
            2, 1,
            height_ratios=[3, 1],
            hspace=0.03
        )

        if col == 3:
            axR = fig.add_subplot(sub[0])
            axG = fig.add_subplot(sub[1], sharex=axR)
        else:
            axR = fig.add_subplot(sub[0], sharey=raster_axes[-1])
            axG = fig.add_subplot(sub[1], sharex=axR, sharey=gna_axes[-1])

        raster_axes.append(axR)
        gna_axes.append(axG)

        plot_raster_gna_ax(
            axR,
            axG,
            dyn_files[k],
            raster_labels[k],
            raster_info[k],
            sim_time=sim_time,
            color=raster_color
        )

        # Formato en k
        axR.yaxis.set_major_formatter(FuncFormatter(k_formatter))
        axG.xaxis.set_major_formatter(FuncFormatter(k_formatter))

        if col == 4:
            axR.set_ylabel("")
            axG.set_ylabel("")
            axR.tick_params(axis="y", labelleft=False)
            axG.tick_params(axis="y", labelleft=False)

        if row == 0:
            axG.set_xlabel("")
            axG.tick_params(axis="x", labelbottom=False)

    plt.show()

# %%
import os


def find_filename2D(parameters2D = None, sigma = 0.5, exc_weight = 8.5, sim_number = 0):

    if parameters2D is None:
        parameters2D = {
            "L": 2.0,
            "rho": 125,
            "soma_diameter": 0.015,
            "d_mean": 0.15,
            "d_sigma": 0.02,
            "l_mean": 1.00,
            "segment_length": 0.01,
            "sigma_axon_angle": 0.1,
            "agg": 1,
            "n_centers": 10,
            "base_sigma": 0.5,
            "BC_type": "SW",
            "geometry": "square"   # "square" or "circle"
    }

    parametersDynamics = {
        "max_exc_weight": 8.5,
        "max_inh_weight": 0.5,
        "noise_max": 3,
        "sim_time": 10000,
        "seed": 42
    }

    alpha = 0.1
    sim = sim_number

    calibration_filename = "figures_TFM/data_for_figures/gini2D_n_grid13_calibration.txt"
    data = np.loadtxt(calibration_filename, skiprows=1)
    base_sigma_values = data[:,1]

    # base_sigma_values = np.linspace(0.04, 0.6, 50)
    MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)


    base_sigma_target = sigma
    MAX_EXC_WEIGHT_target = exc_weight

    base_sigma = base_sigma_values[np.abs(base_sigma_values - base_sigma_target).argmin()]
    MAX_EXC_WEIGHT = MAX_EXC_WEIGHT_values[np.abs(MAX_EXC_WEIGHT_values - MAX_EXC_WEIGHT_target).argmin()]


    # ============================================================
    # FILENAMES
    # ============================================================


    filename_adj_2D = (
        f"2D_dynamics/networks_for_dynamics/"
        f"2D_adjacency_matrix_{parameters2D['geometry']}_{parameters2D['BC_type']}"
        f"_agg_nc{parameters2D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters2D['L']:.1f}_rho{parameters2D['rho']:.0f}"
        f"_l{parameters2D['l_mean']:.2f}_d{parameters2D['d_mean']:.2f}"
        f"_a{alpha:.2f}_sim{sim}.txt"
    )

    filename_dyn_2D = (
        f"2D_dynamics/2D_dynamics_{parameters2D['geometry']}_{parameters2D['BC_type']}"
        f"_agg_nc{parameters2D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters2D['L']:.1f}_rho{parameters2D['rho']:.0f}_l{parameters2D['l_mean']:.2f}_d{parameters2D['d_mean']:.2f}"
        f"_a{alpha:.2f}_exc{MAX_EXC_WEIGHT:.3f}_sim{sim}.txt"
    )

    if not os.path.exists(filename_adj_2D):
        print(f"Archivo no encontrado: {filename_adj_2D}")
    if not os.path.exists(filename_dyn_2D):
        print(f"Archivo no encontrado: {filename_dyn_2D}")
        
    return filename_adj_2D, filename_dyn_2D

def find_filename3D(parameters3D = None, sigma = 0.04, exc_weight = 8.5, sim_number = 0):

    if parameters3D is None:
        parameters3D = {
            "L": 2.0, # Length of the square domain (mm) or diameter of the circular domain (mm)
            "height": 1.0, # Height of the cylinder domain (mm), only used if geometry is "cylinder"
            "rho": 1400, # Neuron density (neurons/mm^2)
            "soma_diameter": 0.015, # Diameter of the soma (mm)
            "d_mean": 0.15, # Dendritic tree diameter (mm) Gaussian distribution
            "d_sigma": 0.02, # Standard deviation of the dendritic tree diameter (mm)
            "l_mean": 1.00, # Mean axon length (mm) Rayleigh distribution
            "segment_length": 0.01, # Segment length for axon growth (mm)
            "sigma_pol": 0.1, # Standard deviation of the axon angle (radians)
            "sigma_azi": 0.1, # Standard deviation of the azimuthal angle (radians)
            "agg": 1, # Control parameter for the aggregation of neurons
            "n_centers": 112, # Number of centers for the aggregation of neurons
            "base_sigma": 0.04, # Base standard deviation for aggregation centers (mm)
            "BC_type": "SW",  # Boundary conditions type (PBC: Periodic Boundary Conditions, SW: Sticky Walls)
            "geometry": "cube", # Geometry of the domain (cube or sphere)
            "seed": 0,
    }

    parametersDynamics = {
        "max_exc_weight": 8.5,
        "max_inh_weight": 0.5,
        "noise_max": 3,
        "sim_time": 10000,
        "seed": 42
    }

    alpha = 0.1
    sim = sim_number

    calibration_filename = "figures_TFM/data_for_figures/gini3D_n_grid13_calibration.txt"
    data = np.loadtxt(calibration_filename, skiprows=1)
    base_sigma_values = data[:,1]

    # base_sigma_values = np.linspace(0.04, 0.6, 50)
    MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)


    base_sigma_target = sigma
    MAX_EXC_WEIGHT_target = exc_weight

    base_sigma = base_sigma_values[np.abs(base_sigma_values - base_sigma_target).argmin()]
    MAX_EXC_WEIGHT = MAX_EXC_WEIGHT_values[np.abs(MAX_EXC_WEIGHT_values - MAX_EXC_WEIGHT_target).argmin()]

    sunset2 = load_cmap("Sunset2", cmap_type="continuous")

    # ============================================================
    # FILENAMES
    # ============================================================

    filename_adj_3D = (
        f"3D_dynamics/networks_for_dynamics/"
        f"3D_adjacency_matrix_{parameters3D['geometry']}_{parameters3D['BC_type']}"
        f"_agg_nc{parameters3D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters3D['L']:.1f}_h{parameters3D['height']:.2f}_rho{parameters3D['rho']:.0f}"
        f"_l{parameters3D['l_mean']:.2f}_d{parameters3D['d_mean']:.2f}"
        f"_a{alpha:.2f}_sim{sim}.txt"
    )

    filename_dyn_3D = (
        f"3D_dynamics/3D_dynamics_{parameters3D['geometry']}_{parameters3D['BC_type']}"
        f"_agg_nc{parameters3D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters3D['L']:.1f}_h{parameters3D['height']:.2f}_rho{parameters3D['rho']:.0f}"
        f"_l{parameters3D['l_mean']:.2f}_d{parameters3D['d_mean']:.2f}"
        f"_a{alpha:.2f}_exc{MAX_EXC_WEIGHT:.3f}_sim{sim}.txt"
    )

    if not os.path.exists(filename_adj_3D):
        print(f"Archivo no encontrado: {filename_adj_3D}")
    if not os.path.exists(filename_dyn_3D):
        print(f"Archivo no encontrado: {filename_dyn_3D}")
    return filename_adj_3D, filename_dyn_3D

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from pypalettes import load_cmap

map_file_2D = "GNA_map_vsGini/GNAmap_square_SW_rho125_l1.00_mean.txt"
map_file_3D = "GNA_map_vsGini/3D_GNAmap_cube_SW_rho1400_l1.00_sim0.txt"

sigma_2D_1 = 0.5
exc_weight_2D_1 = 14
sigma_2D_2 = 0.07
exc_weight_2D_2 = 9.9
sigma_3D_1 = 0.5
exc_weight_3D_1 = 14
sigma_3D_2 = 0.03
exc_weight_3D_2 = 9.8

sim_number = 9
filename_2D_1 = find_filename2D(sigma=sigma_2D_1, exc_weight=exc_weight_2D_1, sim_number = sim_number)[1]
filename_2D_2 = find_filename2D(sigma=sigma_2D_2, exc_weight=exc_weight_2D_2, sim_number = sim_number)[1]
filename_3D_1 = find_filename3D(sigma=sigma_3D_1, exc_weight=exc_weight_3D_1)[1]
filename_3D_2 = find_filename3D(sigma=sigma_3D_2, exc_weight=exc_weight_3D_2)[1]
    
dyn_files = [filename_2D_1, filename_2D_2, filename_3D_1, filename_3D_2]

raster_info = [
    r"$\sigma = $" + f"{sigma_2D_1:.2f}," + r"$E = $" + f"{exc_weight_2D_1:.1f}",
    r"$\sigma = $" + f"{sigma_2D_2:.3f}," + r"$E = $" + f"{exc_weight_2D_2:.1f}",
    r"$\sigma = $" + f"{sigma_3D_1:.2f}," + r"$E = $" + f"{exc_weight_3D_1:.1f}",
    r"$\sigma = $" + f"{sigma_3D_2:.2f}," + r"$E = $" + f"{exc_weight_3D_2:.1f}",
]

cmap = load_cmap("viridis", cmap_type="continuous")
plot_maps_and_rasters_panel(
    map_file_2D,
    map_file_3D,
    dyn_files=dyn_files,
    raster_info=raster_info,
    contour_levels=[0.2, 0.9],
    heatmap_value = "fano_factor",
    cmap = cmap,
    sim_time = 10000,
    figsize=(15.8, 5.2)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      17 exc_weight_3D_2 = 9.8
#      19 sim_number = 9
# ---> 20 filename_2D_1 = find_filename2D(sigma=sigma_2D_1, exc_weight=exc_weight_2D_1, sim_number = sim_number)[1]
#      21 filename_2D_2 = find_filename2D(sigma=sigma_2D_2, exc_weight=exc_weight_2D_2, sim_number = sim_number)[1]
#      22 filename_3D_1 = find_filename3D(sigma=sigma_3D_1, exc_weight=exc_weight_3D_1)[1]
#
# NameError: name 'find_filename2D' is not defined

# %% [markdown]
# # ROC curves

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np


def compute_roc(A, F):

    # -------------------------
    # Simetrizar estructura
    # -------------------------
    F = np.nan_to_num(F, nan=0.0)

    A = ((A + A.T) > 0).astype(int)

    # -------------------------
    # Score funcional
    # -------------------------

    F = np.abs(F)

    # -------------------------
    # Triángulo superior
    # -------------------------

    mask = np.triu(np.ones(A.shape, dtype=bool), k=1)

    y_true = A[mask]
    y_score = F[mask]

    # -------------------------
    # ROC
    # -------------------------

    fpr, tpr, thresholds = roc_curve(y_true, y_score)

    roc_auc = auc(fpr, tpr)

    return fpr, tpr, roc_auc, thresholds

def confusion_at_fpr(A, F, target_fpr=0.1):

    F = np.nan_to_num(F, nan=0.0)
    A = ((A + A.T) > 0).astype(int)
    F = np.abs(F)

    mask = np.triu(np.ones(A.shape, dtype=bool), k=1)

    y_true = A[mask]
    y_score = F[mask]

    fpr, tpr, thresholds = roc_curve(y_true, y_score)

    idx = np.argmin(np.abs(fpr - target_fpr))
    threshold = thresholds[idx]

    y_pred = (y_score >= threshold).astype(int)

    TP = np.sum((y_true == 1) & (y_pred == 1))
    FP = np.sum((y_true == 0) & (y_pred == 1))
    FN = np.sum((y_true == 1) & (y_pred == 0))
    TN = np.sum((y_true == 0) & (y_pred == 0))

    return {
        "threshold": threshold,
        "fpr": FP / (FP + TN),
        "tpr": TP / (TP + FN),
        "TP": TP,
        "FP": FP,
        "FN": FN,
        "TN": TN,
        "P": TP + FN,
        "N": FP + TN
    }

import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix_normalized(res, title=""):

    cm = np.array([
        [res["TP"]/res["P"], res["FN"]/res["P"]],
        [res["FP"]/res["N"], res["TN"]/res["N"]]
    ])

    fig, ax = plt.subplots(figsize=(5,5))

    im = ax.imshow(cm, cmap="Blues", vmin=0, vmax=1)

    labels = [["TPR", "FNR"],
              ["FPR", "TNR"]]

    for i in range(2):
        for j in range(2):
            ax.text(
                j, i,
                f"{labels[i][j]}\n{100*cm[i,j]:.1f}%",
                ha="center",
                va="center",
                fontsize=16,
                color="black"
            )

    ax.set_xticks([0,1])
    ax.set_yticks([0,1])

    ax.set_xticklabels(["Predicted\nconnection",
                        "Predicted\nno connection"], fontsize=14)

    ax.set_yticklabels(["Real\nconnection",
                        "Real\nno connection"], fontsize=14)

    ax.set_title(title, fontsize=18)

    plt.colorbar(im, label="Fraction")
    plt.tight_layout()

# %%
sigma_2D_1 = 0.6
exc_weight_2D_1 = 14
sigma_2D_2 = 0.01
exc_weight_2D_2 = 10
sigma_3D_1 = 0.6
exc_weight_3D_1 = 14
sigma_3D_2 = 0.04
exc_weight_3D_2 = 9.8

filename_adj_2D_1, filename_dyn_2D_1 = find_filename2D(sigma=sigma_2D_1, exc_weight=exc_weight_2D_1)
filename_adj_2D_2, filename_dyn_2D_2 = find_filename2D(sigma=sigma_2D_2, exc_weight=exc_weight_2D_2)
filename_adj_3D_1, filename_dyn_3D_1 = find_filename3D(sigma=sigma_3D_1, exc_weight=exc_weight_3D_1)
filename_adj_3D_2, filename_dyn_3D_2 = find_filename3D(sigma=sigma_3D_2, exc_weight=exc_weight_3D_2)

A_2D_1 = fcn.load_A(filename_adj_2D_1)
A_2D_1_CG = fcn.get_GC(A_2D_1)
N_2D_1 = A_2D_1.shape[0]

A_2D_2 = fcn.load_A(filename_adj_2D_2)
A_2D_2_CG = fcn.get_GC(A_2D_2)
N_2D_2 = A_2D_2.shape[0]

A_3D_1 = fcn.load_A(filename_adj_3D_1)
A_3D_1_CG = fcn.get_GC(A_3D_1)
N_3D_1 = A_3D_1.shape[0]

A_3D_2 = fcn.load_A(filename_adj_3D_2)
A_3D_2_CG = fcn.get_GC(A_3D_2)
N_3D_2 = A_3D_2.shape[0]

firings_2D_1_t, firings_2D_1_i = fcn.load_firings(filename_dyn_2D_1)
firings_2D_2_t, firings_2D_2_i = fcn.load_firings(filename_dyn_2D_2)
firings_3D_1_t, firings_3D_1_i = fcn.load_firings(filename_dyn_3D_1)
firings_3D_2_t, firings_3D_2_i = fcn.load_firings(filename_dyn_3D_2)

functional_connectivity_2D_1 = fcn.build_F_matrix(filename_dyn_2D_1, SIM_TIME=10000, N = N_2D_1)
functional_connectivity_2D_2 = fcn.build_F_matrix(filename_dyn_2D_2, SIM_TIME=10000, N = N_2D_2)
# functional_connectivity_3D_1 = fcn.build_F_matrix(filename_dyn_3D_1, SIM_TIME=10000, N = N_3D_1)
# functional_connectivity_3D_2 = fcn.build_F_matrix(filename_dyn_3D_2, SIM_TIME=10000, N = N_3D_2)

F_binary_2D_1 = functional_connectivity_2D_1[0]
F_binary_2D_2 = functional_connectivity_2D_2[0]
# F_binary_3D_1 = functional_connectivity_3D_1[0]
# F_binary_3D_2 = functional_connectivity_3D_2[0]

# Build ROC curves for each network

fpr_2D_1, tpr_2D_1, roc_auc_2D_1, thresholds_2D_1 = compute_roc(A_2D_1, F_binary_2D_1)
fpr_2D_2, tpr_2D_2, roc_auc_2D_2, thresholds_2D_2 = compute_roc(A_2D_2, F_binary_2D_2)
# fpr_3D_1, tpr_3D_1, roc_auc_3D_1, thresholds_3D_1 = compute_roc(A_3D_1, F_binary_3D_1)
# fpr_3D_2, tpr_3D_2, roc_auc_3D_2, thresholds_3D_2 = compute_roc(A_3D_2, F_binary_3D_2)
# Out:
# N = 495
# F.shape = (495, 495)
# F_binary.shape = (495, 495)
# min firings_i raw = 1
# max firings_i raw = 495
# min firings_i - 1 = 0
# max firings_i - 1 = 494
# N = 497
# F.shape = (497, 497)
# F_binary.shape = (497, 497)
# min firings_i raw = 1
# max firings_i raw = 497
# min firings_i - 1 = 0
# max firings_i - 1 = 496

# %%
viridis = load_cmap("viridis", cmap_type="continuous")

plt.figure(figsize=(6, 5))
plt.plot(fpr_2D_1, tpr_2D_1, label=r"$2D_{ran}$" + f' (AUC = {roc_auc_2D_1:.2f})', color = viridis(0.), lw = 3)
plt.plot(fpr_2D_2, tpr_2D_2, label=r"$2D_{agg}$" + f' (AUC = {roc_auc_2D_2:.2f})', color = viridis(0.4), lw = 3)
# plt.plot(fpr_3D_1, tpr_3D_1, label=r"$3D_{ran}$" + f' (AUC = {roc_auc_3D_1:.2f})', color = viridis(0.6), lw = 3)
# plt.plot(fpr_3D_2, tpr_3D_2, label=r"$3D_{agg}$" + f'(AUC = {roc_auc_3D_2:.2f})', color = viridis(0.9), lw = 3)
plt.plot([0, 1], [0, 1], 'k--')
plt.legend(loc='lower right', fontsize = 16, frameon = False, handlelength=1.)
plt.xlabel('False Positive Rate', fontsize = 20)
plt.ylabel('True Positive Rate', fontsize = 20)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)

plt.figure(figsize=(6, 5))
# plt.plot(fpr_2D_1, thresholds_2D_1, label='Threshold', color = viridis(0.2), lw = 3)
plt.plot(thresholds_2D_2, tpr_2D_2, color = viridis(0.2), lw = 3, label = "TPR 2D")
plt.plot(thresholds_2D_2, fpr_2D_2, color = viridis(0.5), lw = 3, label = "FPR 2D")
# plt.plot(thresholds_3D_2, tpr_3D_2, color = viridis(0.2), lw = 3, ls = "--", label = "TPR 3D")
# plt.plot(thresholds_3D_2, fpr_3D_2, color = viridis(0.5), lw = 3, ls = "--", label = "FPR 3D")
# plt.plot(fpr_2D_2, thresholds_2D_2, label='Threshold', color = viridis(0.4), lw = 3)
# plt.plot(fpr_3D_1, thresholds_3D_1, label='Threshold', color = viridis(0.6), lw = 3)
# plt.plot(fpr_3D_2, thresholds_3D_2, label='Threshold', color = viridis(0.9), lw = 3)
# plt.ylabel('False Positive Rate', fontsize = 20)
plt.xlabel('Threshold', fontsize = 20)
plt.legend(loc='best', fontsize = 16, frameon = False, handlelength=1.5)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)

# Sacar estas curvas para los axones rectos, mirar el clustering y la global effficiency. Mirar la modularidad y clustering de la estructural y funcional. Para apoyar el resultado de los mapas. Mapa Q_funcional/ Q_estrcutural. Mapa Clustering_funcioanl/Clustering_estructural
# Out:
# (array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2]),
#  [Text(0, -0.2, '−0.2'),
#   Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4000000000000001, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0000000000000002, '1.0'),
#   Text(0, 1.2000000000000002, '1.2')])

# %%
res_2D_1 = confusion_at_fpr(A_2D_1, F_binary_2D_1, target_fpr=0.1)
res_2D_2 = confusion_at_fpr(A_2D_2, F_binary_2D_2, target_fpr=0.1)
res_3D_1 = confusion_at_fpr(A_3D_1, F_binary_3D_1, target_fpr=0.1)
res_3D_2 = confusion_at_fpr(A_3D_2, F_binary_3D_2, target_fpr=0.1)

# %%
plot_confusion_matrix_normalized(res_2D_1, "2D random")
plot_confusion_matrix_normalized(res_2D_2, "2D aggregated")
plot_confusion_matrix_normalized(res_3D_1, "3D random")
plot_confusion_matrix_normalized(res_3D_2, "3D aggregated")

# %%
sigma = 0.04
exc_weight = 15

# filename_adj, filename_dyn= find_filename3D(sigma=sigma, exc_weight=exc_weight)
filename_adj, filename_dyn= find_filename2D(sigma=sigma, exc_weight=exc_weight)

A = fcn.load_A(filename_adj)
A = fcn.get_GC(A)
N = A.shape[0]

firings_t, firings_i = fcn.load_firings(filename_dyn)

functional_connectivity = fcn.build_F_matrix(filename_dyn, SIM_TIME=10000, N = N)
F = functional_connectivity[0]

A = ((A + A.T) > 0).astype(int)
F = np.abs(F)

mask = np.triu(np.ones(A.shape, dtype=bool), k=1)

A_flat = A[mask]
F_flat = F[mask]

F_connected = F_flat[A_flat == 1]
F_not_connected = F_flat[A_flat == 0]

# %%
plt.figure(figsize=(6, 5))
viridis = load_cmap("viridis", cmap_type="continuous")
plt.hist(
    F_not_connected,
    bins=50,
    density=True,
    alpha=0.9,
    label="Not connected", 
    color = viridis(0.2)
)

plt.hist(
    F_connected,
    bins=50,
    density=True,
    alpha=0.6,
    label="Connected", 
    color = viridis(0.8)
)

plt.xlabel(r"$|F_{ij}|$", fontsize = 20)
plt.ylabel("Density", fontsize = 20)
plt.xticks(fontsize = 18)
plt.yticks(fontsize = 18)
plt.legend(loc="upper right", fontsize=18, frameon=False)

# %%
import warnings

warnings.filterwarnings("ignore", category=RuntimeWarning)
# Map of tpr at fpr 0.1 vs gini and exc_weight
calibration_filename = "figures_TFM/data_for_figures/gini2D_n_grid13_calibration.txt"
data = np.loadtxt(calibration_filename, skiprows=1)
Gini = data[:,0]
base_sigma_values = data[:,1]

MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)

output_filename = "figures_TFM/data_for_figures/2D_SLR_roc_tpr_at_fpr0.1_map.txt"
with open(output_filename, "w") as f:
    f.write("Gini\tbase_sigma\tMAX_EXC_WEIGHT\ttpr_at_fpr0.1\n")
k = 0
for s in base_sigma_values:
    base_sigma = s
    gini = Gini[k]
    for MAX_EXC_WEIGHT in MAX_EXC_WEIGHT_values:
        exc_weight = MAX_EXC_WEIGHT
        filename_adj, filename_dyn = find_filename2D(sigma=base_sigma, exc_weight=exc_weight)

        A = fcn.load_A(filename_adj)
        A_GC = fcn.get_GC(A)
        N = A.shape[0]

        firings_t, firings_i = fcn.load_firings(filename_dyn)

        functional_connectivity = fcn.build_F_matrix(filename_dyn, SIM_TIME=10000, N = N)

        F = functional_connectivity[0]

        fpr, tpr, roc_auc = compute_roc(A, F)

        tpr_at_fpr01 = np.interp(0.1, fpr, tpr)

        with open(output_filename, "a") as f:
            f.write(f"{gini}\t{base_sigma:.4f}\t{MAX_EXC_WEIGHT:.3f}\t{tpr_at_fpr01:.6f}\n")
            
    print(f"Processed base_sigma = {base_sigma:.4f}, gini = {gini:.4f}")
    k += 1
# Out:
# Processed base_sigma = 0.0446, gini = 0.8700
# Processed base_sigma = 0.0513, gini = 0.8598
# Processed base_sigma = 0.0571, gini = 0.8496
# Processed base_sigma = 0.0622, gini = 0.8394
# Processed base_sigma = 0.0671, gini = 0.8292
# Processed base_sigma = 0.0718, gini = 0.8190
# Processed base_sigma = 0.0764, gini = 0.8088
# Processed base_sigma = 0.0811, gini = 0.7986
# Processed base_sigma = 0.0858, gini = 0.7884
# Processed base_sigma = 0.0904, gini = 0.7782
# Processed base_sigma = 0.0949, gini = 0.7680
# Processed base_sigma = 0.0992, gini = 0.7578
# Processed base_sigma = 0.1031, gini = 0.7476
# Processed base_sigma = 0.1070, gini = 0.7373
# Processed base_sigma = 0.1109, gini = 0.7271
# Processed base_sigma = 0.1146, gini = 0.7169
# Processed base_sigma = 0.1184, gini = 0.7067
# Processed base_sigma = 0.1222, gini = 0.6965
# Processed base_sigma = 0.1265, gini = 0.6863
# Processed base_sigma = 0.1310, gini = 0.6761
# Processed base_sigma = 0.1358, gini = 0.6659
# Processed base_sigma = 0.1408, gini = 0.6557
# Processed base_sigma = 0.1458, gini = 0.6455
# Processed base_sigma = 0.1506, gini = 0.6353
# Processed base_sigma = 0.1557, gini = 0.6251
# Processed base_sigma = 0.1612, gini = 0.6149
# Processed base_sigma = 0.1675, gini = 0.6047
# Processed base_sigma = 0.1741, gini = 0.5945
# Processed base_sigma = 0.1802, gini = 0.5843
# Processed base_sigma = 0.1858, gini = 0.5741
# Processed base_sigma = 0.1912, gini = 0.5639
# Processed base_sigma = 0.1971, gini = 0.5537
# Processed base_sigma = 0.2047, gini = 0.5435
# Processed base_sigma = 0.2173, gini = 0.5333
# Processed base_sigma = 0.2293, gini = 0.5231
# Processed base_sigma = 0.2374, gini = 0.5129
# Processed base_sigma = 0.2451, gini = 0.5027
# Processed base_sigma = 0.2543, gini = 0.4924
# Processed base_sigma = 0.2659, gini = 0.4822
# Processed base_sigma = 0.2892, gini = 0.4720
# Processed base_sigma = 0.3034, gini = 0.4618
# Processed base_sigma = 0.3103, gini = 0.4516
# Processed base_sigma = 0.3169, gini = 0.4414
# Processed base_sigma = 0.3263, gini = 0.4312
# Processed base_sigma = 0.3514, gini = 0.4210
# Processed base_sigma = 0.3951, gini = 0.4108
# Processed base_sigma = 0.4060, gini = 0.4006
# Processed base_sigma = 0.4503, gini = 0.3904
# Processed base_sigma = 0.4978, gini = 0.3802
# Processed base_sigma = 0.5314, gini = 0.3700

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from pypalettes import create_cmap, load_cmap

cmapC = load_cmap("berlin", cmap_type="continuous")
map_clustering = "figures_TFM/data_for_figures/2D_roc_tpr_at_fpr0.1_map.txt"

df = pd.read_csv(map_clustering, sep=r"\s+")

# Matriz: filas = excitación, columnas = Gini
pivot = df.pivot_table(
    index="MAX_EXC_WEIGHT",
    columns="Gini",
    values="tpr_at_fpr0.1",
    aggfunc="mean"
).sort_index().sort_index(axis=1)

x = pivot.columns.to_numpy(dtype=float)      # Gini
y = pivot.index.to_numpy(dtype=float)        # Excitatory weight
Z = pivot.to_numpy(dtype=float)

# Suavizado opcional
Z = gaussian_filter(Z, sigma=0.01)
# Z_diff = np.abs(1-Z)

X, Y = np.meshgrid(x, y)

fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(
    Z,
    origin="lower",
    aspect="auto",
    extent=[x.min(), x.max(), y.min(), y.max()],
    cmap=cmapC, 
    # interpolation="bilinear"
)

# contours = ax.contour(
#     X, Y, Z_smooth,
#     levels=[0.2, 0.5, 0.9],
#     colors="white",
#     linewidths=2
# )

# ax.clabel(
#     contours,
#     inline=True,
#     fontsize=13,
#     fmt="%.2f",
#     colors="white"
# )

ax.set_xlabel(r"$\Lambda$", fontsize=20)
ax.set_ylabel(r"$E$", fontsize=20)

ax.tick_params(labelsize=14)

# Título estilo imagen
# ax.text(
#     # 0.02, 1.02, "A) 2D",
#     transform=ax.transAxes,
#     fontsize=20,
#     ha="left",
#     va="bottom"
# )

cbar = plt.colorbar(im, ax=ax, pad=0.02)
cbar.set_label(
    r"$|1-C_{F}/C_{S}|$",
    fontsize=15
)
cbar.ax.tick_params(labelsize=18)

plt.tight_layout()
plt.show()

# %%
import os
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import importlib
import functions_create_networks as fcn
importlib.reload(fcn)

warnings.filterwarnings("ignore", category=RuntimeWarning)

# -----------------------------
# Parámetros
# -----------------------------

calibration_filename = "figures_TFM/data_for_figures/gini3D_n_grid13_calibration.txt"
output_filename = "figures_TFM/data_for_figures/3D_roc_tpr_at_fpr0.1_curves_average.txt"

SIM_TIME = 10000
sims = 1
target_fpr = 0.1

MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)

# Escoge aquí dos valores objetivo
# Puede ser por Gini:
gini_targets = [0.3, 0.9]

# O, si prefieres por base_sigma, comenta lo anterior y usa esto:
# base_sigma_targets = [0.05, 0.40]


# -----------------------------
# Cargar calibración Gini-sigma
# -----------------------------

data = np.loadtxt(calibration_filename, skiprows=1)
Gini_values = data[:, 0]
base_sigma_values = data[:, 1]


def find_closest_by_gini(gini_target):
    idx = np.argmin(np.abs(Gini_values - gini_target))
    return Gini_values[idx], base_sigma_values[idx]


def find_closest_by_sigma(sigma_target):
    idx = np.argmin(np.abs(base_sigma_values - sigma_target))
    return Gini_values[idx], base_sigma_values[idx]


# -----------------------------
# Seleccionar las dos curvas
# -----------------------------

selected_curves = []

for gini_target in gini_targets:
    gini_real, sigma_real = find_closest_by_gini(gini_target)
    selected_curves.append((gini_real, sigma_real))

# Si prefieres elegir por sigma, sustituye el bloque anterior por:
# selected_curves = []
# for sigma_target in base_sigma_targets:
#     gini_real, sigma_real = find_closest_by_sigma(sigma_target)
#     selected_curves.append((gini_real, sigma_real))


# -----------------------------
# Calcular curvas promediadas
# -----------------------------

rows = []

for gini, base_sigma in selected_curves:

    print(f"\nProcesando curva: Gini={gini:.4f}, base_sigma={base_sigma:.4f}")

    for exc_weight in MAX_EXC_WEIGHT_values:

        tpr_values = []
        auc_values = []

        for sim in range(sims):

            filename_adj, filename_dyn = find_filename3D(
                sigma=base_sigma,
                exc_weight=exc_weight,
                sim_number=sim
            )

            if (not os.path.exists(filename_adj)) or (not os.path.exists(filename_dyn)):
                print(f"No existe sim {sim}: sigma={base_sigma:.4f}, E={exc_weight:.3f}")
                continue

            A = fcn.load_A(filename_adj)
            N = A.shape[0]

            F = fcn.build_F_for_roc(
                filename_dyn,
                SIM_TIME=SIM_TIME,
                N=N
            )

            fpr, tpr, roc_auc, _ = compute_roc(A, F)

            order = np.argsort(fpr)
            fpr = fpr[order]
            tpr = tpr[order]

            tpr_at_fpr01 = np.interp(target_fpr, fpr, tpr)

            tpr_values.append(tpr_at_fpr01)
            auc_values.append(roc_auc)

        if len(tpr_values) == 0:
            mean_tpr = np.nan
            std_tpr = np.nan
            mean_auc = np.nan
            std_auc = np.nan
            n_sims = 0
        else:
            mean_tpr = np.mean(tpr_values)
            std_tpr = np.std(tpr_values)
            mean_auc = np.mean(auc_values)
            std_auc = np.std(auc_values)
            n_sims = len(tpr_values)

        rows.append({
            "Gini": gini,
            "base_sigma": base_sigma,
            "MAX_EXC_WEIGHT": exc_weight,
            "tpr_at_fpr0.1_mean": mean_tpr,
            "tpr_at_fpr0.1_std": std_tpr,
            "auc_mean": mean_auc,
            "auc_std": std_auc,
            "n_sims": n_sims
        })

df_out = pd.DataFrame(rows)
df_out.to_csv(output_filename, sep="\t", index=False)

print(f"\nGuardado en: {output_filename}")
# Out:
# Procesando curva: Gini=0.3700, base_sigma=0.4544
#
# Procesando curva: Gini=0.8450, base_sigma=0.0317
#
# Guardado en: figures_TFM/data_for_figures/3D_roc_tpr_at_fpr0.1_curves_average.txt

# %%
output_filename2D = "figures_TFM/data_for_figures/2D_roc_tpr_at_fpr0.1_curves_average.txt"
output_filename3D = "figures_TFM/data_for_figures/3D_roc_tpr_at_fpr0.1_curves_average.txt"
df2D = pd.read_csv(output_filename2D, sep="\t")
df3D = pd.read_csv(output_filename3D, sep="\t")

plt.figure(figsize=(6, 5))

viridis = load_cmap("viridis", cmap_type="continuous")

colors = [viridis(0.0), viridis(0.4), viridis(0.6), viridis(0.9)]
labels2D = [r"$2D_{ran}$", r"$2D_{agg}$"]
labels3D = [r"$3D_{ran}$", r"$3D_{agg}$"]
k = 0
for (gini, base_sigma), group in df2D.groupby(["Gini", "base_sigma"]):

    group = group.sort_values("MAX_EXC_WEIGHT")

    x = group["MAX_EXC_WEIGHT"].to_numpy()
    y = group["tpr_at_fpr0.1_mean"].to_numpy()
    yerr = group["tpr_at_fpr0.1_std"].to_numpy()

    plt.plot(
        x, y,
        "-",
        lw = 3,
        label=labels2D[k], 
        color=colors[k]
    )

    plt.fill_between(
        x,
        y - yerr,
        y + yerr,
        alpha=0.2, 
        color = colors[k]
    )
    k +=1

k = 0
c = 0
for (gini, base_sigma), group in df3D.groupby(["Gini", "base_sigma"]):

    group = group.sort_values("MAX_EXC_WEIGHT")

    x = group["MAX_EXC_WEIGHT"].to_numpy()
    y = group["tpr_at_fpr0.1_mean"].to_numpy()
    yerr = group["tpr_at_fpr0.1_std"].to_numpy()

    plt.plot(
        x, y,
        "--",
        lw = 3,
        label=labels3D[k], 
        color=colors[k]
    )

    # plt.fill_between(
    #     x,
    #     y - yerr,
    #     y + yerr,
    #     alpha=0.2, 
    #     color = colors[k]
    # )
    k +=1
    c+=1

plt.xlabel("E", fontsize = 20)
plt.ylabel(r"TPR at FPR = 0.1", fontsize = 20)
plt.xticks([2, 5, 10, 15, 20], fontsize = 18)
plt.yticks(fontsize = 18)
plt.legend(fontsize = 14, frameon = False, handlelength=1.5)
# plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

filename = "figures_TFM/data_for_figures/2D_roc_tpr_at_fpr0.1_map.txt"
df = pd.read_csv(filename, sep=r"\s+")

# Ginis que quieres comparar
gini_targets = [0.3, 0.9]

plt.figure(figsize=(5,4))

for g in gini_targets:

    # Gini disponible más cercano
    g_real = df["Gini"].iloc[np.argmin(np.abs(df["Gini"] - g))]

    curve = (
        df[np.isclose(df["Gini"], g_real)]
        .sort_values("MAX_EXC_WEIGHT")
    )

    plt.plot(
        curve["MAX_EXC_WEIGHT"],
        curve["tpr_at_fpr0.1"],
        "-o",
        ms=4,
        label=fr"$\Lambda={g_real:.3f}$"
    )

plt.xlabel("Excitatory weight")
plt.ylabel(r"TPR at FPR = 0.1")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Violin plots

# %%
sigma_2D_1 = 0.6
exc_weight_2D_1 = 17.5
sigma_2D_2 = 0.04
exc_weight_2D_2 = 15
sigma_3D_1 = 0.6
exc_weight_3D_1 = 17.5
sigma_3D_2 = 0.04
exc_weight_3D_2 = 15

filename_adj_2D_1, filename_dyn_2D_1 = find_filename2D(sigma=sigma_2D_1, exc_weight=exc_weight_2D_1)
filename_adj_2D_2, filename_dyn_2D_2 = find_filename2D(sigma=sigma_2D_2, exc_weight=exc_weight_2D_2)
filename_adj_3D_1, filename_dyn_3D_1 = find_filename3D(sigma=sigma_3D_1, exc_weight=exc_weight_3D_1)
filename_adj_3D_2, filename_dyn_3D_2 = find_filename3D(sigma=sigma_3D_2, exc_weight=exc_weight_3D_2)

A_2D_1 = fcn.load_A(filename_adj_2D_1)
A_2D_1_CG = fcn.get_GC(A_2D_1)
N_2D_1 = A_2D_1.shape[0]

A_2D_2 = fcn.load_A(filename_adj_2D_2)
A_2D_2_CG = fcn.get_GC(A_2D_2)
N_2D_2 = A_2D_2.shape[0]

A_3D_1 = fcn.load_A(filename_adj_3D_1)
A_3D_1_CG = fcn.get_GC(A_3D_1)
N_3D_1 = A_3D_1.shape[0]

A_3D_2 = fcn.load_A(filename_adj_3D_2)
A_3D_2_CG = fcn.get_GC(A_3D_2)
N_3D_2 = A_3D_2.shape[0]

firings_2D_1_t, firings_2D_1_i = fcn.load_firings(filename_dyn_2D_1)
firings_2D_2_t, firings_2D_2_i = fcn.load_firings(filename_dyn_2D_2)
firings_3D_1_t, firings_3D_1_i = fcn.load_firings(filename_dyn_3D_1)
firings_3D_2_t, firings_3D_2_i = fcn.load_firings(filename_dyn_3D_2)
import numpy as np
import matplotlib.pyplot as plt


def get_peak_heights(firings_t, firings_i, N, SIM_TIME=10000, W=25):
    GNA = fcn.compute_GNA_from_raster(
        firings_t=firings_t,
        firings_i=firings_i,
        N=N,
        SIM_TIME=SIM_TIME,
        W=W
    )

    peaks, peak_heights, mean_peaks_height, std_peaks_height = fcn.find_GNA_peaks(GNA)

    return peak_heights, mean_peaks_height, std_peaks_height


peak_heights_2D_1, mean_2D_1, std_2D_1 = get_peak_heights(
    firings_2D_1_t, firings_2D_1_i, N_2D_1,
    SIM_TIME=10000, W=25
)

peak_heights_2D_2, mean_2D_2, std_2D_2 = get_peak_heights(
    firings_2D_2_t, firings_2D_2_i, N_2D_2,
    SIM_TIME=10000, W=25
)

peak_heights_3D_1, mean_3D_1, std_3D_1 = get_peak_heights(
    firings_3D_1_t, firings_3D_1_i, N_3D_1,
    SIM_TIME=10000, W=25
)

peak_heights_3D_2, mean_3D_2, std_3D_2 = get_peak_heights(
    firings_3D_2_t, firings_3D_2_i, N_3D_2,
    SIM_TIME=10000, W=25
)

# %%
def plot_peak_height_strip(
    peak_heights_list,
    labels,
    positions=None,
    colors=None,
    jitter=0.12,
    figsize=(7, 4.5),
    point_size=18,
    alpha=0.55
):
    rng = np.random.default_rng(123)

    if positions is None:
        positions = np.arange(len(peak_heights_list))

    if colors is None:
        colors = plt.cm.viridis(np.linspace(0.15, 0.85, len(peak_heights_list)))

    fig, ax = plt.subplots(figsize=figsize)

    for i, peak_heights in enumerate(peak_heights_list):
        peak_heights = np.asarray(peak_heights, dtype=float)
        peak_heights = peak_heights[np.isfinite(peak_heights)]

        x0 = positions[i]
        x = x0 + rng.uniform(-jitter, jitter, size=len(peak_heights))

        ax.scatter(
            x,
            peak_heights,
            s=point_size,
            alpha=alpha,
            color=colors[i],
            edgecolor="none"
        )

        mean_val = np.mean(peak_heights)

        ax.hlines(
            mean_val,
            x0 - 0.1,
            x0 + 0.1,
            color="black",
            linewidth=1.5
        )

    ax.set_xticks(positions)
    ax.set_xticklabels(labels, fontsize=16)
    ax.tick_params(labelsize=18)

    ax.set_ylabel("GNA peak height", fontsize=18)
    ax.set_ylim(0, 1.05)

    # ax.spines["top"].set_visible(False)
    # ax.spines["right"].set_visible(False)

    fig.tight_layout()
    return fig, ax

# %%
def collect_peak_heights_2D(sigma, exc_weight, sims=10, SIM_TIME=10000, W=25):
    all_peak_heights = []

    for sim in range(sims):
        filename_adj, filename_dyn = find_filename2D(
            sigma=sigma,
            exc_weight=exc_weight,
            sim_number=sim
        )

        if not os.path.exists(filename_adj) or not os.path.exists(filename_dyn):
            continue

        A = fcn.load_A(filename_adj)
        N = A.shape[0]

        firings_t, firings_i = fcn.load_firings(filename_dyn)

        peak_heights, _, _ = get_peak_heights(
            firings_t, firings_i, N,
            SIM_TIME=SIM_TIME,
            W=W
        )

        all_peak_heights.extend(peak_heights)

    return np.asarray(all_peak_heights)

def collect_peak_heights_3D(sigma, exc_weight, sims=1, SIM_TIME=10000, W=25):
    all_peak_heights = []

    for sim in range(sims):
        filename_adj, filename_dyn = find_filename3D(
            sigma=sigma,
            exc_weight=exc_weight,
            sim_number=sim
        )

        if not os.path.exists(filename_adj) or not os.path.exists(filename_dyn):
            continue

        A = fcn.load_A(filename_adj)
        N = A.shape[0]

        firings_t, firings_i = fcn.load_firings(filename_dyn)

        peak_heights, _, _ = get_peak_heights(
            firings_t, firings_i, N,
            SIM_TIME=SIM_TIME,
            W=W
        )

        all_peak_heights.extend(peak_heights)

    return np.asarray(all_peak_heights)

peak_heights_2D_1 = collect_peak_heights_2D(
    sigma=sigma_2D_1,
    exc_weight=exc_weight_2D_1,
    sims=10
)

peak_heights_2D_2 = collect_peak_heights_2D(
    sigma=sigma_2D_2,
    exc_weight=exc_weight_2D_2,
    sims=10
)

peak_heights_3D_1 = collect_peak_heights_3D(
    sigma=sigma_3D_1,
    exc_weight=exc_weight_3D_1,
    sims=1
)

peak_heights_3D_2 = collect_peak_heights_3D(
    sigma=sigma_3D_2,
    exc_weight=exc_weight_3D_2,
    sims=1
)

# %%
def plot_peak_height_violin_strip(
    peak_heights_list,
    labels,
    positions=None,
    colors=None,
    jitter=0.10,
    figsize=(6, 4.5),
    point_size=16,
    alpha_points=0.45,
    violin_alpha=0.35
):

    rng = np.random.default_rng(123)

    if positions is None:
        positions = np.arange(len(peak_heights_list))

    if colors is None:
        colors = plt.cm.viridis(
            np.linspace(0.15, 0.85, len(peak_heights_list))
        )

    fig, ax = plt.subplots(figsize=figsize)

    # ==========================================================
    # VIOLIN
    # ==========================================================
    vp = ax.violinplot(
        peak_heights_list,
        positions=positions,
        widths=0.22,
        showmeans=False,
        showmedians=False,
        showextrema=False,
    )

    for body, color in zip(vp["bodies"], colors):
        body.set_facecolor(color)
        body.set_edgecolor("none")
        body.set_alpha(violin_alpha)
        body.set_zorder(5)
    

    # ==========================================================
    # STRIP
    # ==========================================================

    for i, peak_heights in enumerate(peak_heights_list):

        peak_heights = np.asarray(peak_heights, dtype=float)
        peak_heights = peak_heights[np.isfinite(peak_heights)]

        x0 = positions[i]

        x = x0 + rng.uniform(
            -jitter,
            jitter,
            size=len(peak_heights)
        )

        ax.scatter(
            x,
            peak_heights,
            s=point_size,
            alpha=alpha_points,
            color=colors[i],
            edgecolor="black",
            linewidths=0.1,
            zorder=3,
        )

        mean_val = np.mean(peak_heights)

        ax.hlines(
            mean_val,
            x0 - 0.10,
            x0 + 0.10,
            color="black",
            linewidth=2.0,
            zorder=4
        )

    
    # ==========================================================
    # FORMAT
    # ==========================================================

    ax.set_xticks(positions)
    ax.set_xticklabels(labels, fontsize=18)

    ax.set_ylabel("GNA peak height", fontsize=20)

    ax.tick_params(labelsize=18)

    ax.set_ylim(0, 1.05)

    fig.tight_layout()

    return fig, ax

# %%
from matplotlib.lines import Line2D

peak_heights_list = [
    peak_heights_2D_1,
    peak_heights_2D_2,
    peak_heights_3D_1,
    peak_heights_3D_2
]

labels = [
    r"$2D_{ran}$",
    r"$2D_{agg}$",
    r"$3D_{ran}$",
    r"$3D_{agg}$"
]

colors = plt.cm.viridis(
    np.linspace(0.15, 0.85, len(peak_heights_list))
)
legend_elements = [

    Line2D(
        [0], [0],
        marker='o',
        color='w',
        markerfacecolor=colors[0],
        markersize=8,
        label=f"{sigma_2D_1}   {exc_weight_2D_1:.1f}"
    ),

    Line2D(
        [0], [0],
        marker='o',
        color='w',
        markerfacecolor=colors[1],
        markersize=8,
        label=f"{sigma_2D_2}   {exc_weight_2D_2:.1f}"
    ),

    Line2D(
        [0], [0],
        marker='o',
        color='w',
        markerfacecolor=colors[2],
        markersize=8,
        label=f"{sigma_3D_1}   {exc_weight_3D_1:.1f}"
    ),

    Line2D(
        [0], [0],
        marker='o',
        color='w',
        markerfacecolor=colors[3],
        markersize=8,
        label=f"{sigma_3D_2}   {exc_weight_3D_2:.1f}"
    ),
]

# leg = ax.legend(
#     handles=legend_elements,
#     title=r"         $\sigma \;\;\;\; E$",
#     fontsize=11,
#     title_fontsize=12,
#     frameon=False,
#     loc="lower right",
#     handletextpad=0.8
# )

# ax.legend(
#     handles=legend_elements,
#     fontsize=10,
#     frameon=False,
#     loc="lower right"
# )

positions = [0, 0.3, 0.6, 0.9]

fig, ax = plot_peak_height_violin_strip(
    peak_heights_list,
    labels,
    positions=positions,
    figsize=(5, 4.5),
    jitter=0.10,
    point_size=16,
alpha_points=0.6, 
violin_alpha=0.5
)

plt.legend(
    handles=legend_elements,
    fontsize=13,
    title=r"          $\sigma \;\;\;\;\;\;\;\;\;\;\;\; E$",
    title_fontsize=12,
    frameon=False,
    loc="best"
)

plt.show()

# %% [markdown]
# # Maps of modularity and clustering coefficient for structural and functional networks

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from scipy.signal import find_peaks
from pypalettes import load_cmap
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import importlib
import functions_create_networks as fcn
importlib.reload(fcn)

from matplotlib.ticker import FuncFormatter


def find_filename2D(parameters2D = None, sigma = 0.5, exc_weight = 8.5, sim_number = 0):

    if parameters2D is None:
        parameters2D = {
            "L": 2.0,
            "rho": 125,
            "soma_diameter": 0.015,
            "d_mean": 0.15,
            "d_sigma": 0.02,
            "l_mean": 1.00,
            "segment_length": 0.01,
            "sigma_axon_angle": 0.1,
            "agg": 1,
            "n_centers": 10,
            "base_sigma": 0.5,
            "BC_type": "SW",
            "geometry": "squareLongRange"   # "square" or "circle"
    }

    parametersDynamics = {
        "max_exc_weight": 8.5,
        "max_inh_weight": 0.5,
        "noise_max": 3,
        "sim_time": 10000,
        "seed": 42
    }

    alpha = 0.1
    sim = sim_number

    calibration_filename = "figures_TFM/data_for_figures/gini2D_n_grid13_calibration.txt"
    data = np.loadtxt(calibration_filename, skiprows=1)
    base_sigma_values = data[:,1]

    # base_sigma_values = np.linspace(0.04, 0.6, 50)
    MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)


    base_sigma_target = sigma
    MAX_EXC_WEIGHT_target = exc_weight

    base_sigma = base_sigma_values[np.abs(base_sigma_values - base_sigma_target).argmin()]
    MAX_EXC_WEIGHT = MAX_EXC_WEIGHT_values[np.abs(MAX_EXC_WEIGHT_values - MAX_EXC_WEIGHT_target).argmin()]


    # ============================================================
    # FILENAMES
    # ============================================================


    filename_adj_2D = (
        f"2D_dynamics/networks_for_dynamics/"
        f"2D_adjacency_matrix_{parameters2D['geometry']}_{parameters2D['BC_type']}"
        f"_agg_nc{parameters2D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters2D['L']:.1f}_rho{parameters2D['rho']:.0f}"
        f"_l{parameters2D['l_mean']:.2f}_d{parameters2D['d_mean']:.2f}"
        f"_a{alpha:.2f}_sim{sim}.txt"
    )

    filename_dyn_2D = (
        f"2D_dynamics/2D_dynamics_{parameters2D['geometry']}_{parameters2D['BC_type']}"
        f"_agg_nc{parameters2D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters2D['L']:.1f}_rho{parameters2D['rho']:.0f}_l{parameters2D['l_mean']:.2f}_d{parameters2D['d_mean']:.2f}"
        f"_a{alpha:.2f}_exc{MAX_EXC_WEIGHT:.3f}_sim{sim}.txt"
    )

    if not os.path.exists(filename_adj_2D):
        print(f"Archivo no encontrado: {filename_adj_2D}")
    if not os.path.exists(filename_dyn_2D):
        print(f"Archivo no encontrado: {filename_dyn_2D}")
        
    return filename_adj_2D, filename_dyn_2D

def find_filename3D(parameters3D = None, sigma = 0.04, exc_weight = 8.5, sim_number = 0):

    if parameters3D is None:
        parameters3D = {
            "L": 2.0, # Length of the square domain (mm) or diameter of the circular domain (mm)
            "height": 1.0, # Height of the cylinder domain (mm), only used if geometry is "cylinder"
            "rho": 1400, # Neuron density (neurons/mm^2)
            "soma_diameter": 0.015, # Diameter of the soma (mm)
            "d_mean": 0.15, # Dendritic tree diameter (mm) Gaussian distribution
            "d_sigma": 0.02, # Standard deviation of the dendritic tree diameter (mm)
            "l_mean": 1.00, # Mean axon length (mm) Rayleigh distribution
            "segment_length": 0.01, # Segment length for axon growth (mm)
            "sigma_pol": 0.1, # Standard deviation of the axon angle (radians)
            "sigma_azi": 0.1, # Standard deviation of the azimuthal angle (radians)
            "agg": 1, # Control parameter for the aggregation of neurons
            "n_centers": 112, # Number of centers for the aggregation of neurons
            "base_sigma": 0.04, # Base standard deviation for aggregation centers (mm)
            "BC_type": "SW",  # Boundary conditions type (PBC: Periodic Boundary Conditions, SW: Sticky Walls)
            "geometry": "cube", # Geometry of the domain (cube or sphere)
            "seed": 0,
    }

    parametersDynamics = {
        "max_exc_weight": 8.5,
        "max_inh_weight": 0.5,
        "noise_max": 3,
        "sim_time": 10000,
        "seed": 42
    }

    alpha = 0.1
    sim = sim_number

    calibration_filename = "figures_TFM/data_for_figures/gini3D_n_grid13_calibration.txt"
    data = np.loadtxt(calibration_filename, skiprows=1)
    base_sigma_values = data[:,1]

    # base_sigma_values = np.linspace(0.04, 0.6, 50)
    MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)


    base_sigma_target = sigma
    MAX_EXC_WEIGHT_target = exc_weight

    base_sigma = base_sigma_values[np.abs(base_sigma_values - base_sigma_target).argmin()]
    MAX_EXC_WEIGHT = MAX_EXC_WEIGHT_values[np.abs(MAX_EXC_WEIGHT_values - MAX_EXC_WEIGHT_target).argmin()]

    sunset2 = load_cmap("Sunset2", cmap_type="continuous")

    # ============================================================
    # FILENAMES
    # ============================================================

    filename_adj_3D = (
        f"3D_dynamics/networks_for_dynamics/"
        f"3D_adjacency_matrix_{parameters3D['geometry']}_{parameters3D['BC_type']}"
        f"_agg_nc{parameters3D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters3D['L']:.1f}_h{parameters3D['height']:.2f}_rho{parameters3D['rho']:.0f}"
        f"_l{parameters3D['l_mean']:.2f}_d{parameters3D['d_mean']:.2f}"
        f"_a{alpha:.2f}_sim{sim}.txt"
    )

    filename_dyn_3D = (
        f"3D_dynamics/3D_dynamics_{parameters3D['geometry']}_{parameters3D['BC_type']}"
        f"_agg_nc{parameters3D['n_centers']}_s{base_sigma:.4f}"
        f"_L{parameters3D['L']:.1f}_h{parameters3D['height']:.2f}_rho{parameters3D['rho']:.0f}"
        f"_l{parameters3D['l_mean']:.2f}_d{parameters3D['d_mean']:.2f}"
        f"_a{alpha:.2f}_exc{MAX_EXC_WEIGHT:.3f}_sim{sim}.txt"
    )

    if not os.path.exists(filename_adj_3D):
        print(f"Archivo no encontrado: {filename_adj_3D}")
    if not os.path.exists(filename_dyn_3D):
        print(f"Archivo no encontrado: {filename_dyn_3D}")
    return filename_adj_3D, filename_dyn_3D

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

calibration_filename = "figures_TFM/data_for_figures/gini2D_n_grid13_calibration.txt"
data = np.loadtxt(calibration_filename, skiprows=1)
gini_values = data[:,0]
base_sigma_values = data[:,1]

MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)

def louvain_modularity(A):
    import networkx as nx

    G = nx.from_numpy_array(A)

    if G.number_of_edges() == 0:
        return np.nan

    communities = nx.community.louvain_communities(G, seed=0)
    modularity = nx.community.modularity(G, communities)

    return modularity
def compute_clustering_coefficient(A):
    import networkx as nx

    G = nx.from_numpy_array(A)

    if G.number_of_edges() == 0:
        return np.nan

    clustering_coeffs = nx.clustering(G)
    average_clustering = np.mean(list(clustering_coeffs.values()))

    return average_clustering

sims = 10
for sim in range(sims):
    out_filename_modularity = f"figures_TFM/data_for_figures/modularity_map_2D_sim_{sim}.txt"
    out_filename_clustering = f"figures_TFM/data_for_figures/clustering_map_2D_sim_{sim}.txt"
    k = 0
    with open(out_filename_modularity, "w") as f:
        f.write("sigma\tgini\texc_weight\tmodF\tmodA\tmodF/modA\n")
    with open(out_filename_clustering, "w") as f:
        f.write("sigma\tgini\texc_weight\tclusF\tclusA\tclusF/clusA\n")
    for sigma in base_sigma_values:
        gini = gini_values[k]
        filename_adj_2D, _= find_filename2D(sigma=sigma, exc_weight=MAX_EXC_WEIGHT_values[0], sim_number=sim)
        if not os.path.exists(filename_adj_2D):
            print(f"Archivo no encontrado para sigma={sigma:.4f}")
            continue
        A_2D = fcn.load_A(filename_adj_2D)
        A_2D = ((A_2D + A_2D.T) > 0).astype(int)  # Ensure the adjacency matrix is symmetric and binary
        modularity_2D = louvain_modularity(A_2D)
        clustering_2D = compute_clustering_coefficient(A_2D)
        for exc_weight in MAX_EXC_WEIGHT_values:

            _, filename_dyn_2D = find_filename2D(sigma=sigma, exc_weight=exc_weight, sim_number=sim)
            if not os.path.exists(filename_dyn_2D):
                print(f"Archivo no encontrado para sigma={sigma:.4f}, exc_weight={exc_weight:.1f}")
                continue

            F, F_binary, F_ordered, order, communities = fcn.build_F_matrix(filename_dyn_2D, SIM_TIME = 10000, N = A_2D.shape[0])
            F_binary = ((F_binary + F_binary.T) > 0).astype(int)  # Ensure the functional connectivity matrix is symmetric and binary
            modularity_F_2D = louvain_modularity(F_binary)
            clustering_F_2D = compute_clustering_coefficient(F_binary)
            modularity_ratio_2D = modularity_F_2D / modularity_2D if modularity_2D != 0 else np.nan

            print(f"Sigma: {sigma:.4f}, Gini: {gini:.4f}, Exc Weight: {exc_weight:.1f}, Modularity F 2D: {modularity_F_2D:.4f}, Modularity A 2D: {modularity_2D:.4f}, Ratio: {modularity_ratio_2D:.4f}")
            print(f"Sigma: {sigma:.4f}, Gini: {gini:.4f}, Exc Weight: {exc_weight:.1f}, Clustering F 2D: {clustering_F_2D:.4f}, Clustering A 2D: {clustering_2D:.4f}, Ratio: {clustering_F_2D/clustering_2D:.4f}")
            with open(out_filename_modularity, "a") as f:
                f.write(f"{sigma:.4f}\t{gini:.4f}\t{exc_weight:.1f}\t{modularity_F_2D:.4f}\t{modularity_2D:.4f}\t{modularity_ratio_2D:.4f}\n")
            with open(out_filename_clustering, "a") as f:
                f.write(f"{sigma:.4f}\t{gini:.4f}\t{exc_weight:.1f}\t{clustering_F_2D:.4f}\t{clustering_2D:.4f}\t{clustering_F_2D/clustering_2D:.4f}\n")
        k += 1
# Out:
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 2.0, Modularity F 2D: 0.1185, Modularity A 2D: 0.5513, Ratio: 0.2149
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 2.0, Clustering F 2D: 0.4319, Clustering A 2D: 0.4506, Ratio: 0.9584
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 2.4, Modularity F 2D: 0.1185, Modularity A 2D: 0.5513, Ratio: 0.2150
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 2.4, Clustering F 2D: 0.4910, Clustering A 2D: 0.4506, Ratio: 1.0896
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 2.7, Modularity F 2D: 0.1385, Modularity A 2D: 0.5513, Ratio: 0.2512
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 2.7, Clustering F 2D: 0.4949, Clustering A 2D: 0.4506, Ratio: 1.0983
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 3.1, Modularity F 2D: 0.1408, Modularity A 2D: 0.5513, Ratio: 0.2554
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 3.1, Clustering F 2D: 0.4786, Clustering A 2D: 0.4506, Ratio: 1.0622
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 3.5, Modularity F 2D: 0.1139, Modularity A 2D: 0.5513, Ratio: 0.2065
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 3.5, Clustering F 2D: 0.4549, Clustering A 2D: 0.4506, Ratio: 1.0095
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 3.8, Modularity F 2D: 0.1198, Modularity A 2D: 0.5513, Ratio: 0.2172
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 3.8, Clustering F 2D: 0.4084, Clustering A 2D: 0.4506, Ratio: 0.9064
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 4.2, Modularity F 2D: 0.1190, Modularity A 2D: 0.5513, Ratio: 0.2158
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 4.2, Clustering F 2D: 0.4035, Clustering A 2D: 0.4506, Ratio: 0.8954
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 4.6, Modularity F 2D: 0.1169, Modularity A 2D: 0.5513, Ratio: 0.2120
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 4.6, Clustering F 2D: 0.4643, Clustering A 2D: 0.4506, Ratio: 1.0304
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 4.9, Modularity F 2D: 0.1211, Modularity A 2D: 0.5513, Ratio: 0.2196
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 4.9, Clustering F 2D: 0.4640, Clustering A 2D: 0.4506, Ratio: 1.0297
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 5.3, Modularity F 2D: 0.1210, Modularity A 2D: 0.5513, Ratio: 0.2195
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 5.3, Clustering F 2D: 0.4721, Clustering A 2D: 0.4506, Ratio: 1.0477
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 5.7, Modularity F 2D: 0.1368, Modularity A 2D: 0.5513, Ratio: 0.2481
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 5.7, Clustering F 2D: 0.4465, Clustering A 2D: 0.4506, Ratio: 0.9908
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 6.0, Modularity F 2D: 0.1354, Modularity A 2D: 0.5513, Ratio: 0.2455
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 6.0, Clustering F 2D: 0.4310, Clustering A 2D: 0.4506, Ratio: 0.9565
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 6.4, Modularity F 2D: 0.1327, Modularity A 2D: 0.5513, Ratio: 0.2407
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 6.4, Clustering F 2D: 0.4433, Clustering A 2D: 0.4506, Ratio: 0.9839
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 6.8, Modularity F 2D: 0.1493, Modularity A 2D: 0.5513, Ratio: 0.2708
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 6.8, Clustering F 2D: 0.3736, Clustering A 2D: 0.4506, Ratio: 0.8292
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 7.1, Modularity F 2D: 0.1572, Modularity A 2D: 0.5513, Ratio: 0.2852
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 7.1, Clustering F 2D: 0.3510, Clustering A 2D: 0.4506, Ratio: 0.7791
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 7.5, Modularity F 2D: 0.1564, Modularity A 2D: 0.5513, Ratio: 0.2836
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 7.5, Clustering F 2D: 0.3674, Clustering A 2D: 0.4506, Ratio: 0.8154
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 7.9, Modularity F 2D: 0.1713, Modularity A 2D: 0.5513, Ratio: 0.3107
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 7.9, Clustering F 2D: 0.3698, Clustering A 2D: 0.4506, Ratio: 0.8206
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 8.2, Modularity F 2D: 0.1882, Modularity A 2D: 0.5513, Ratio: 0.3413
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 8.2, Clustering F 2D: 0.3418, Clustering A 2D: 0.4506, Ratio: 0.7585
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 8.6, Modularity F 2D: 0.2674, Modularity A 2D: 0.5513, Ratio: 0.4849
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 8.6, Clustering F 2D: 0.2982, Clustering A 2D: 0.4506, Ratio: 0.6618
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 9.0, Modularity F 2D: 0.2186, Modularity A 2D: 0.5513, Ratio: 0.3965
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 9.0, Clustering F 2D: 0.3026, Clustering A 2D: 0.4506, Ratio: 0.6716
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 9.3, Modularity F 2D: 0.2211, Modularity A 2D: 0.5513, Ratio: 0.4010
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 9.3, Clustering F 2D: 0.2950, Clustering A 2D: 0.4506, Ratio: 0.6546
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 9.7, Modularity F 2D: 0.4991, Modularity A 2D: 0.5513, Ratio: 0.9052
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 9.7, Clustering F 2D: 0.5870, Clustering A 2D: 0.4506, Ratio: 1.3027
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 10.1, Modularity F 2D: 0.4063, Modularity A 2D: 0.5513, Ratio: 0.7370
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 10.1, Clustering F 2D: 0.5976, Clustering A 2D: 0.4506, Ratio: 1.3263
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 10.4, Modularity F 2D: 0.4799, Modularity A 2D: 0.5513, Ratio: 0.8705
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 10.4, Clustering F 2D: 0.5532, Clustering A 2D: 0.4506, Ratio: 1.2277
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 10.8, Modularity F 2D: 0.4408, Modularity A 2D: 0.5513, Ratio: 0.7994
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 10.8, Clustering F 2D: 0.5552, Clustering A 2D: 0.4506, Ratio: 1.2322
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 11.2, Modularity F 2D: 0.5345, Modularity A 2D: 0.5513, Ratio: 0.9695
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 11.2, Clustering F 2D: 0.6257, Clustering A 2D: 0.4506, Ratio: 1.3886
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 11.6, Modularity F 2D: 0.4527, Modularity A 2D: 0.5513, Ratio: 0.8211
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 11.6, Clustering F 2D: 0.5761, Clustering A 2D: 0.4506, Ratio: 1.2786
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 11.9, Modularity F 2D: 0.4552, Modularity A 2D: 0.5513, Ratio: 0.8256
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 11.9, Clustering F 2D: 0.5579, Clustering A 2D: 0.4506, Ratio: 1.2380
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 12.3, Modularity F 2D: 0.4999, Modularity A 2D: 0.5513, Ratio: 0.9067
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 12.3, Clustering F 2D: 0.5924, Clustering A 2D: 0.4506, Ratio: 1.3148
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 12.7, Modularity F 2D: 0.3971, Modularity A 2D: 0.5513, Ratio: 0.7203
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 12.7, Clustering F 2D: 0.5480, Clustering A 2D: 0.4506, Ratio: 1.2161
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 13.0, Modularity F 2D: 0.4945, Modularity A 2D: 0.5513, Ratio: 0.8970
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 13.0, Clustering F 2D: 0.5640, Clustering A 2D: 0.4506, Ratio: 1.2517
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 13.4, Modularity F 2D: 0.4567, Modularity A 2D: 0.5513, Ratio: 0.8284
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 13.4, Clustering F 2D: 0.5823, Clustering A 2D: 0.4506, Ratio: 1.2923
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 13.8, Modularity F 2D: 0.5132, Modularity A 2D: 0.5513, Ratio: 0.9308
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 13.8, Clustering F 2D: 0.5785, Clustering A 2D: 0.4506, Ratio: 1.2839
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 14.1, Modularity F 2D: 0.4540, Modularity A 2D: 0.5513, Ratio: 0.8235
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 14.1, Clustering F 2D: 0.6000, Clustering A 2D: 0.4506, Ratio: 1.3315
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 14.5, Modularity F 2D: 0.4043, Modularity A 2D: 0.5513, Ratio: 0.7333
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 14.5, Clustering F 2D: 0.5962, Clustering A 2D: 0.4506, Ratio: 1.3232
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 14.9, Modularity F 2D: 0.5080, Modularity A 2D: 0.5513, Ratio: 0.9215
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 14.9, Clustering F 2D: 0.5625, Clustering A 2D: 0.4506, Ratio: 1.2483
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 15.2, Modularity F 2D: 0.4006, Modularity A 2D: 0.5513, Ratio: 0.7266
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 15.2, Clustering F 2D: 0.5385, Clustering A 2D: 0.4506, Ratio: 1.1951
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 15.6, Modularity F 2D: 0.5131, Modularity A 2D: 0.5513, Ratio: 0.9306
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 15.6, Clustering F 2D: 0.5919, Clustering A 2D: 0.4506, Ratio: 1.3137
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 16.0, Modularity F 2D: 0.4607, Modularity A 2D: 0.5513, Ratio: 0.8356
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 16.0, Clustering F 2D: 0.5493, Clustering A 2D: 0.4506, Ratio: 1.2191
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 16.3, Modularity F 2D: 0.2980, Modularity A 2D: 0.5513, Ratio: 0.5406
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 16.3, Clustering F 2D: 0.5218, Clustering A 2D: 0.4506, Ratio: 1.1580
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 16.7, Modularity F 2D: 0.4839, Modularity A 2D: 0.5513, Ratio: 0.8776
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 16.7, Clustering F 2D: 0.5798, Clustering A 2D: 0.4506, Ratio: 1.2867
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 17.1, Modularity F 2D: 0.4567, Modularity A 2D: 0.5513, Ratio: 0.8284
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 17.1, Clustering F 2D: 0.5406, Clustering A 2D: 0.4506, Ratio: 1.1998
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 17.4, Modularity F 2D: 0.3957, Modularity A 2D: 0.5513, Ratio: 0.7177
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 17.4, Clustering F 2D: 0.5318, Clustering A 2D: 0.4506, Ratio: 1.1802
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 17.8, Modularity F 2D: 0.3697, Modularity A 2D: 0.5513, Ratio: 0.6705
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 17.8, Clustering F 2D: 0.5082, Clustering A 2D: 0.4506, Ratio: 1.1278
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 18.2, Modularity F 2D: 0.4912, Modularity A 2D: 0.5513, Ratio: 0.8910
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 18.2, Clustering F 2D: 0.5528, Clustering A 2D: 0.4506, Ratio: 1.2268
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 18.5, Modularity F 2D: 0.4621, Modularity A 2D: 0.5513, Ratio: 0.8382
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 18.5, Clustering F 2D: 0.5650, Clustering A 2D: 0.4506, Ratio: 1.2539
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 18.9, Modularity F 2D: 0.5516, Modularity A 2D: 0.5513, Ratio: 1.0004
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 18.9, Clustering F 2D: 0.5687, Clustering A 2D: 0.4506, Ratio: 1.2620
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 19.3, Modularity F 2D: 0.4026, Modularity A 2D: 0.5513, Ratio: 0.7302
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 19.3, Clustering F 2D: 0.5502, Clustering A 2D: 0.4506, Ratio: 1.2210
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 19.6, Modularity F 2D: 0.3770, Modularity A 2D: 0.5513, Ratio: 0.6838
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 19.6, Clustering F 2D: 0.5346, Clustering A 2D: 0.4506, Ratio: 1.1863
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 20.0, Modularity F 2D: 0.4597, Modularity A 2D: 0.5513, Ratio: 0.8338
# Sigma: 0.0446, Gini: 0.8700, Exc Weight: 20.0, Clustering F 2D: 0.5633, Clustering A 2D: 0.4506, Ratio: 1.2501
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 2.0, Modularity F 2D: 0.1365, Modularity A 2D: 0.4401, Ratio: 0.3101
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 2.0, Clustering F 2D: 0.4673, Clustering A 2D: 0.4481, Ratio: 1.0427
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 2.4, Modularity F 2D: 0.1209, Modularity A 2D: 0.4401, Ratio: 0.2748
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 2.4, Clustering F 2D: 0.4662, Clustering A 2D: 0.4481, Ratio: 1.0404
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 2.7, Modularity F 2D: 0.1132, Modularity A 2D: 0.4401, Ratio: 0.2571
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 2.7, Clustering F 2D: 0.4924, Clustering A 2D: 0.4481, Ratio: 1.0988
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 3.1, Modularity F 2D: 0.1176, Modularity A 2D: 0.4401, Ratio: 0.2672
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 3.1, Clustering F 2D: 0.5017, Clustering A 2D: 0.4481, Ratio: 1.1196
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 3.5, Modularity F 2D: 0.1259, Modularity A 2D: 0.4401, Ratio: 0.2860
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 3.5, Clustering F 2D: 0.4534, Clustering A 2D: 0.4481, Ratio: 1.0117
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 3.8, Modularity F 2D: 0.1401, Modularity A 2D: 0.4401, Ratio: 0.3182
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 3.8, Clustering F 2D: 0.4593, Clustering A 2D: 0.4481, Ratio: 1.0249
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 4.2, Modularity F 2D: 0.1280, Modularity A 2D: 0.4401, Ratio: 0.2907
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 4.2, Clustering F 2D: 0.4390, Clustering A 2D: 0.4481, Ratio: 0.9797
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 4.6, Modularity F 2D: 0.1246, Modularity A 2D: 0.4401, Ratio: 0.2832
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 4.6, Clustering F 2D: 0.4303, Clustering A 2D: 0.4481, Ratio: 0.9602
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 4.9, Modularity F 2D: 0.1330, Modularity A 2D: 0.4401, Ratio: 0.3023
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 4.9, Clustering F 2D: 0.4183, Clustering A 2D: 0.4481, Ratio: 0.9335
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 5.3, Modularity F 2D: 0.1307, Modularity A 2D: 0.4401, Ratio: 0.2970
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 5.3, Clustering F 2D: 0.4030, Clustering A 2D: 0.4481, Ratio: 0.8994
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 5.7, Modularity F 2D: 0.1359, Modularity A 2D: 0.4401, Ratio: 0.3089
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 5.7, Clustering F 2D: 0.4717, Clustering A 2D: 0.4481, Ratio: 1.0527
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 6.0, Modularity F 2D: 0.1422, Modularity A 2D: 0.4401, Ratio: 0.3232
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 6.0, Clustering F 2D: 0.4185, Clustering A 2D: 0.4481, Ratio: 0.9339
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 6.4, Modularity F 2D: 0.1354, Modularity A 2D: 0.4401, Ratio: 0.3077
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 6.4, Clustering F 2D: 0.4132, Clustering A 2D: 0.4481, Ratio: 0.9221
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 6.8, Modularity F 2D: 0.1432, Modularity A 2D: 0.4401, Ratio: 0.3253
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 6.8, Clustering F 2D: 0.3989, Clustering A 2D: 0.4481, Ratio: 0.8902
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 7.1, Modularity F 2D: 0.1646, Modularity A 2D: 0.4401, Ratio: 0.3740
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 7.1, Clustering F 2D: 0.3459, Clustering A 2D: 0.4481, Ratio: 0.7720
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 7.5, Modularity F 2D: 0.1863, Modularity A 2D: 0.4401, Ratio: 0.4233
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 7.5, Clustering F 2D: 0.3435, Clustering A 2D: 0.4481, Ratio: 0.7664
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 7.9, Modularity F 2D: 0.1994, Modularity A 2D: 0.4401, Ratio: 0.4532
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 7.9, Clustering F 2D: 0.3172, Clustering A 2D: 0.4481, Ratio: 0.7079
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 8.2, Modularity F 2D: 0.2483, Modularity A 2D: 0.4401, Ratio: 0.5641
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 8.2, Clustering F 2D: 0.3476, Clustering A 2D: 0.4481, Ratio: 0.7756
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 8.6, Modularity F 2D: 0.2630, Modularity A 2D: 0.4401, Ratio: 0.5976
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 8.6, Clustering F 2D: 0.3172, Clustering A 2D: 0.4481, Ratio: 0.7078
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 9.0, Modularity F 2D: 0.2614, Modularity A 2D: 0.4401, Ratio: 0.5940
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 9.0, Clustering F 2D: 0.5816, Clustering A 2D: 0.4481, Ratio: 1.2979
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 9.3, Modularity F 2D: 0.2503, Modularity A 2D: 0.4401, Ratio: 0.5688
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 9.3, Clustering F 2D: 0.5445, Clustering A 2D: 0.4481, Ratio: 1.2151
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 9.7, Modularity F 2D: 0.2600, Modularity A 2D: 0.4401, Ratio: 0.5907
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 9.7, Clustering F 2D: 0.5726, Clustering A 2D: 0.4481, Ratio: 1.2777
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 10.1, Modularity F 2D: 0.2847, Modularity A 2D: 0.4401, Ratio: 0.6468
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 10.1, Clustering F 2D: 0.5619, Clustering A 2D: 0.4481, Ratio: 1.2539
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 10.4, Modularity F 2D: 0.2705, Modularity A 2D: 0.4401, Ratio: 0.6146
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 10.4, Clustering F 2D: 0.5269, Clustering A 2D: 0.4481, Ratio: 1.1757
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 10.8, Modularity F 2D: 0.1690, Modularity A 2D: 0.4401, Ratio: 0.3840
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 10.8, Clustering F 2D: 0.5522, Clustering A 2D: 0.4481, Ratio: 1.2322
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 11.2, Modularity F 2D: 0.2845, Modularity A 2D: 0.4401, Ratio: 0.6465
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 11.2, Clustering F 2D: 0.5346, Clustering A 2D: 0.4481, Ratio: 1.1929
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 11.6, Modularity F 2D: 0.3354, Modularity A 2D: 0.4401, Ratio: 0.7620
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 11.6, Clustering F 2D: 0.5708, Clustering A 2D: 0.4481, Ratio: 1.2737
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 11.9, Modularity F 2D: 0.2398, Modularity A 2D: 0.4401, Ratio: 0.5448
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 11.9, Clustering F 2D: 0.5063, Clustering A 2D: 0.4481, Ratio: 1.1299
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 12.3, Modularity F 2D: 0.2340, Modularity A 2D: 0.4401, Ratio: 0.5317
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 12.3, Clustering F 2D: 0.5231, Clustering A 2D: 0.4481, Ratio: 1.1673
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 12.7, Modularity F 2D: 0.2174, Modularity A 2D: 0.4401, Ratio: 0.4940
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 12.7, Clustering F 2D: 0.4716, Clustering A 2D: 0.4481, Ratio: 1.0523
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 13.0, Modularity F 2D: 0.2662, Modularity A 2D: 0.4401, Ratio: 0.6049
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 13.0, Clustering F 2D: 0.5048, Clustering A 2D: 0.4481, Ratio: 1.1264
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 13.4, Modularity F 2D: 0.2508, Modularity A 2D: 0.4401, Ratio: 0.5699
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 13.4, Clustering F 2D: 0.5198, Clustering A 2D: 0.4481, Ratio: 1.1600
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 13.8, Modularity F 2D: 0.3055, Modularity A 2D: 0.4401, Ratio: 0.6942
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 13.8, Clustering F 2D: 0.4917, Clustering A 2D: 0.4481, Ratio: 1.0972
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 14.1, Modularity F 2D: 0.2470, Modularity A 2D: 0.4401, Ratio: 0.5613
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 14.1, Clustering F 2D: 0.5029, Clustering A 2D: 0.4481, Ratio: 1.1223
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 14.5, Modularity F 2D: 0.2961, Modularity A 2D: 0.4401, Ratio: 0.6727
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 14.5, Clustering F 2D: 0.5319, Clustering A 2D: 0.4481, Ratio: 1.1868
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 14.9, Modularity F 2D: 0.3307, Modularity A 2D: 0.4401, Ratio: 0.7514
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 14.9, Clustering F 2D: 0.5100, Clustering A 2D: 0.4481, Ratio: 1.1381
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 15.2, Modularity F 2D: 0.3178, Modularity A 2D: 0.4401, Ratio: 0.7221
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 15.2, Clustering F 2D: 0.5094, Clustering A 2D: 0.4481, Ratio: 1.1368
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 15.6, Modularity F 2D: 0.4095, Modularity A 2D: 0.4401, Ratio: 0.9305
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 15.6, Clustering F 2D: 0.5323, Clustering A 2D: 0.4481, Ratio: 1.1878
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 16.0, Modularity F 2D: 0.2608, Modularity A 2D: 0.4401, Ratio: 0.5926
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 16.0, Clustering F 2D: 0.5392, Clustering A 2D: 0.4481, Ratio: 1.2033
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 16.3, Modularity F 2D: 0.2397, Modularity A 2D: 0.4401, Ratio: 0.5446
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 16.3, Clustering F 2D: 0.4961, Clustering A 2D: 0.4481, Ratio: 1.1072
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 16.7, Modularity F 2D: 0.3825, Modularity A 2D: 0.4401, Ratio: 0.8692
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 16.7, Clustering F 2D: 0.5782, Clustering A 2D: 0.4481, Ratio: 1.2903
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 17.1, Modularity F 2D: 0.3439, Modularity A 2D: 0.4401, Ratio: 0.7814
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 17.1, Clustering F 2D: 0.4889, Clustering A 2D: 0.4481, Ratio: 1.0910
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 17.4, Modularity F 2D: 0.2339, Modularity A 2D: 0.4401, Ratio: 0.5314
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 17.4, Clustering F 2D: 0.5145, Clustering A 2D: 0.4481, Ratio: 1.1481
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 17.8, Modularity F 2D: 0.2408, Modularity A 2D: 0.4401, Ratio: 0.5472
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 17.8, Clustering F 2D: 0.4713, Clustering A 2D: 0.4481, Ratio: 1.0517
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 18.2, Modularity F 2D: 0.4240, Modularity A 2D: 0.4401, Ratio: 0.9634
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 18.2, Clustering F 2D: 0.5359, Clustering A 2D: 0.4481, Ratio: 1.1959
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 18.5, Modularity F 2D: 0.3025, Modularity A 2D: 0.4401, Ratio: 0.6872
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 18.5, Clustering F 2D: 0.5330, Clustering A 2D: 0.4481, Ratio: 1.1893
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 18.9, Modularity F 2D: 0.2951, Modularity A 2D: 0.4401, Ratio: 0.6705
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 18.9, Clustering F 2D: 0.4653, Clustering A 2D: 0.4481, Ratio: 1.0384
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 19.3, Modularity F 2D: 0.2826, Modularity A 2D: 0.4401, Ratio: 0.6421
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 19.3, Clustering F 2D: 0.4951, Clustering A 2D: 0.4481, Ratio: 1.1048
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 19.6, Modularity F 2D: 0.2954, Modularity A 2D: 0.4401, Ratio: 0.6711
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 19.6, Clustering F 2D: 0.4470, Clustering A 2D: 0.4481, Ratio: 0.9975
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 20.0, Modularity F 2D: 0.2945, Modularity A 2D: 0.4401, Ratio: 0.6692
# Sigma: 0.0513, Gini: 0.8598, Exc Weight: 20.0, Clustering F 2D: 0.4986, Clustering A 2D: 0.4481, Ratio: 1.1126
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 2.0, Modularity F 2D: 0.1267, Modularity A 2D: 0.5323, Ratio: 0.2381
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 2.0, Clustering F 2D: 0.4432, Clustering A 2D: 0.4371, Ratio: 1.0139
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 2.4, Modularity F 2D: 0.1229, Modularity A 2D: 0.5323, Ratio: 0.2308
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 2.4, Clustering F 2D: 0.4862, Clustering A 2D: 0.4371, Ratio: 1.1123
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 2.7, Modularity F 2D: 0.1137, Modularity A 2D: 0.5323, Ratio: 0.2137
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 2.7, Clustering F 2D: 0.4729, Clustering A 2D: 0.4371, Ratio: 1.0818
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 3.1, Modularity F 2D: 0.1452, Modularity A 2D: 0.5323, Ratio: 0.2728
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 3.1, Clustering F 2D: 0.4761, Clustering A 2D: 0.4371, Ratio: 1.0892
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 3.5, Modularity F 2D: 0.1472, Modularity A 2D: 0.5323, Ratio: 0.2765
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 3.5, Clustering F 2D: 0.5061, Clustering A 2D: 0.4371, Ratio: 1.1578
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 3.8, Modularity F 2D: 0.1357, Modularity A 2D: 0.5323, Ratio: 0.2550
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 3.8, Clustering F 2D: 0.4531, Clustering A 2D: 0.4371, Ratio: 1.0365
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 4.2, Modularity F 2D: 0.1232, Modularity A 2D: 0.5323, Ratio: 0.2314
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 4.2, Clustering F 2D: 0.4507, Clustering A 2D: 0.4371, Ratio: 1.0310
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 4.6, Modularity F 2D: 0.1269, Modularity A 2D: 0.5323, Ratio: 0.2384
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 4.6, Clustering F 2D: 0.4593, Clustering A 2D: 0.4371, Ratio: 1.0506
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 4.9, Modularity F 2D: 0.1343, Modularity A 2D: 0.5323, Ratio: 0.2523
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 4.9, Clustering F 2D: 0.3693, Clustering A 2D: 0.4371, Ratio: 0.8447
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 5.3, Modularity F 2D: 0.1351, Modularity A 2D: 0.5323, Ratio: 0.2538
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 5.3, Clustering F 2D: 0.3694, Clustering A 2D: 0.4371, Ratio: 0.8451
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 5.7, Modularity F 2D: 0.1312, Modularity A 2D: 0.5323, Ratio: 0.2465
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 5.7, Clustering F 2D: 0.4267, Clustering A 2D: 0.4371, Ratio: 0.9761
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 6.0, Modularity F 2D: 0.1445, Modularity A 2D: 0.5323, Ratio: 0.2714
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 6.0, Clustering F 2D: 0.3824, Clustering A 2D: 0.4371, Ratio: 0.8748
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 6.4, Modularity F 2D: 0.1508, Modularity A 2D: 0.5323, Ratio: 0.2832
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 6.4, Clustering F 2D: 0.3780, Clustering A 2D: 0.4371, Ratio: 0.8647
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 6.8, Modularity F 2D: 0.1348, Modularity A 2D: 0.5323, Ratio: 0.2533
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 6.8, Clustering F 2D: 0.4031, Clustering A 2D: 0.4371, Ratio: 0.9221
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 7.1, Modularity F 2D: 0.1529, Modularity A 2D: 0.5323, Ratio: 0.2871
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 7.1, Clustering F 2D: 0.4000, Clustering A 2D: 0.4371, Ratio: 0.9151
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 7.5, Modularity F 2D: 0.1663, Modularity A 2D: 0.5323, Ratio: 0.3124
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 7.5, Clustering F 2D: 0.3715, Clustering A 2D: 0.4371, Ratio: 0.8498
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 7.9, Modularity F 2D: 0.3370, Modularity A 2D: 0.5323, Ratio: 0.6330
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 7.9, Clustering F 2D: 0.4098, Clustering A 2D: 0.4371, Ratio: 0.9373
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 8.2, Modularity F 2D: 0.4069, Modularity A 2D: 0.5323, Ratio: 0.7644
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 8.2, Clustering F 2D: 0.4696, Clustering A 2D: 0.4371, Ratio: 1.0742
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 8.6, Modularity F 2D: 0.3347, Modularity A 2D: 0.5323, Ratio: 0.6287
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 8.6, Clustering F 2D: 0.6082, Clustering A 2D: 0.4371, Ratio: 1.3914
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 9.0, Modularity F 2D: 0.4460, Modularity A 2D: 0.5323, Ratio: 0.8378
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 9.0, Clustering F 2D: 0.6608, Clustering A 2D: 0.4371, Ratio: 1.5116
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 9.3, Modularity F 2D: 0.4960, Modularity A 2D: 0.5323, Ratio: 0.9318
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 9.3, Clustering F 2D: 0.6428, Clustering A 2D: 0.4371, Ratio: 1.4705
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 9.7, Modularity F 2D: 0.4242, Modularity A 2D: 0.5323, Ratio: 0.7968
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 9.7, Clustering F 2D: 0.6243, Clustering A 2D: 0.4371, Ratio: 1.4282
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 10.1, Modularity F 2D: 0.4874, Modularity A 2D: 0.5323, Ratio: 0.9155
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 10.1, Clustering F 2D: 0.6327, Clustering A 2D: 0.4371, Ratio: 1.4474
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 10.4, Modularity F 2D: 0.5214, Modularity A 2D: 0.5323, Ratio: 0.9794
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 10.4, Clustering F 2D: 0.6347, Clustering A 2D: 0.4371, Ratio: 1.4520
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 10.8, Modularity F 2D: 0.5072, Modularity A 2D: 0.5323, Ratio: 0.9528
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 10.8, Clustering F 2D: 0.5925, Clustering A 2D: 0.4371, Ratio: 1.3553
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 11.2, Modularity F 2D: 0.4341, Modularity A 2D: 0.5323, Ratio: 0.8155
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 11.2, Clustering F 2D: 0.5971, Clustering A 2D: 0.4371, Ratio: 1.3658
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 11.6, Modularity F 2D: 0.4191, Modularity A 2D: 0.5323, Ratio: 0.7873
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 11.6, Clustering F 2D: 0.5917, Clustering A 2D: 0.4371, Ratio: 1.3536
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 11.9, Modularity F 2D: 0.4953, Modularity A 2D: 0.5323, Ratio: 0.9303
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 11.9, Clustering F 2D: 0.5832, Clustering A 2D: 0.4371, Ratio: 1.3340
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 12.3, Modularity F 2D: 0.3784, Modularity A 2D: 0.5323, Ratio: 0.7108
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 12.3, Clustering F 2D: 0.5955, Clustering A 2D: 0.4371, Ratio: 1.3623
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 12.7, Modularity F 2D: 0.5431, Modularity A 2D: 0.5323, Ratio: 1.0202
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 12.7, Clustering F 2D: 0.6190, Clustering A 2D: 0.4371, Ratio: 1.4161
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 13.0, Modularity F 2D: 0.4819, Modularity A 2D: 0.5323, Ratio: 0.9052
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 13.0, Clustering F 2D: 0.5998, Clustering A 2D: 0.4371, Ratio: 1.3720
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 13.4, Modularity F 2D: 0.4819, Modularity A 2D: 0.5323, Ratio: 0.9052
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 13.4, Clustering F 2D: 0.5723, Clustering A 2D: 0.4371, Ratio: 1.3093
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 13.8, Modularity F 2D: 0.5115, Modularity A 2D: 0.5323, Ratio: 0.9609
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 13.8, Clustering F 2D: 0.5981, Clustering A 2D: 0.4371, Ratio: 1.3681
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 14.1, Modularity F 2D: 0.4156, Modularity A 2D: 0.5323, Ratio: 0.7806
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 14.1, Clustering F 2D: 0.5737, Clustering A 2D: 0.4371, Ratio: 1.3124
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 14.5, Modularity F 2D: 0.4486, Modularity A 2D: 0.5323, Ratio: 0.8426
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 14.5, Clustering F 2D: 0.5961, Clustering A 2D: 0.4371, Ratio: 1.3637
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 14.9, Modularity F 2D: 0.3819, Modularity A 2D: 0.5323, Ratio: 0.7174
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 14.9, Clustering F 2D: 0.5810, Clustering A 2D: 0.4371, Ratio: 1.3291
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 15.2, Modularity F 2D: 0.5373, Modularity A 2D: 0.5323, Ratio: 1.0093
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 15.2, Clustering F 2D: 0.5729, Clustering A 2D: 0.4371, Ratio: 1.3106
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 15.6, Modularity F 2D: 0.5100, Modularity A 2D: 0.5323, Ratio: 0.9580
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 15.6, Clustering F 2D: 0.5740, Clustering A 2D: 0.4371, Ratio: 1.3131
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 16.0, Modularity F 2D: 0.3617, Modularity A 2D: 0.5323, Ratio: 0.6794
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 16.0, Clustering F 2D: 0.5763, Clustering A 2D: 0.4371, Ratio: 1.3184
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 16.3, Modularity F 2D: 0.4560, Modularity A 2D: 0.5323, Ratio: 0.8566
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 16.3, Clustering F 2D: 0.5740, Clustering A 2D: 0.4371, Ratio: 1.3131
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 16.7, Modularity F 2D: 0.4451, Modularity A 2D: 0.5323, Ratio: 0.8362
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 16.7, Clustering F 2D: 0.5679, Clustering A 2D: 0.4371, Ratio: 1.2990
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 17.1, Modularity F 2D: 0.5024, Modularity A 2D: 0.5323, Ratio: 0.9437
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 17.1, Clustering F 2D: 0.5944, Clustering A 2D: 0.4371, Ratio: 1.3598
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 17.4, Modularity F 2D: 0.5964, Modularity A 2D: 0.5323, Ratio: 1.1203
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 17.4, Clustering F 2D: 0.6163, Clustering A 2D: 0.4371, Ratio: 1.4098
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 17.8, Modularity F 2D: 0.5439, Modularity A 2D: 0.5323, Ratio: 1.0216
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 17.8, Clustering F 2D: 0.5627, Clustering A 2D: 0.4371, Ratio: 1.2872
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 18.2, Modularity F 2D: 0.4905, Modularity A 2D: 0.5323, Ratio: 0.9214
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 18.2, Clustering F 2D: 0.5646, Clustering A 2D: 0.4371, Ratio: 1.2916
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 18.5, Modularity F 2D: 0.5405, Modularity A 2D: 0.5323, Ratio: 1.0153
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 18.5, Clustering F 2D: 0.5728, Clustering A 2D: 0.4371, Ratio: 1.3103
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 18.9, Modularity F 2D: 0.4962, Modularity A 2D: 0.5323, Ratio: 0.9322
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 18.9, Clustering F 2D: 0.5805, Clustering A 2D: 0.4371, Ratio: 1.3278
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 19.3, Modularity F 2D: 0.5211, Modularity A 2D: 0.5323, Ratio: 0.9789
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 19.3, Clustering F 2D: 0.5632, Clustering A 2D: 0.4371, Ratio: 1.2884
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 19.6, Modularity F 2D: 0.5300, Modularity A 2D: 0.5323, Ratio: 0.9957
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 19.6, Clustering F 2D: 0.6068, Clustering A 2D: 0.4371, Ratio: 1.3881
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 20.0, Modularity F 2D: 0.4557, Modularity A 2D: 0.5323, Ratio: 0.8561
# Sigma: 0.0571, Gini: 0.8496, Exc Weight: 20.0, Clustering F 2D: 0.5687, Clustering A 2D: 0.4371, Ratio: 1.3010
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 2.0, Modularity F 2D: 0.1142, Modularity A 2D: 0.5691, Ratio: 0.2008
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 2.0, Clustering F 2D: 0.5002, Clustering A 2D: 0.4150, Ratio: 1.2051
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 2.4, Modularity F 2D: 0.1170, Modularity A 2D: 0.5691, Ratio: 0.2057
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 2.4, Clustering F 2D: 0.4366, Clustering A 2D: 0.4150, Ratio: 1.0518
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 2.7, Modularity F 2D: 0.1265, Modularity A 2D: 0.5691, Ratio: 0.2223
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 2.7, Clustering F 2D: 0.4346, Clustering A 2D: 0.4150, Ratio: 1.0472
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 3.1, Modularity F 2D: 0.1360, Modularity A 2D: 0.5691, Ratio: 0.2390
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 3.1, Clustering F 2D: 0.4659, Clustering A 2D: 0.4150, Ratio: 1.1225
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 3.5, Modularity F 2D: 0.1243, Modularity A 2D: 0.5691, Ratio: 0.2185
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 3.5, Clustering F 2D: 0.4888, Clustering A 2D: 0.4150, Ratio: 1.1778
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 3.8, Modularity F 2D: 0.1185, Modularity A 2D: 0.5691, Ratio: 0.2082
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 3.8, Clustering F 2D: 0.4868, Clustering A 2D: 0.4150, Ratio: 1.1728
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 4.2, Modularity F 2D: 0.1212, Modularity A 2D: 0.5691, Ratio: 0.2129
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 4.2, Clustering F 2D: 0.4710, Clustering A 2D: 0.4150, Ratio: 1.1348
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 4.6, Modularity F 2D: 0.1237, Modularity A 2D: 0.5691, Ratio: 0.2175
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 4.6, Clustering F 2D: 0.4404, Clustering A 2D: 0.4150, Ratio: 1.0611
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 4.9, Modularity F 2D: 0.1276, Modularity A 2D: 0.5691, Ratio: 0.2242
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 4.9, Clustering F 2D: 0.4328, Clustering A 2D: 0.4150, Ratio: 1.0428
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 5.3, Modularity F 2D: 0.1306, Modularity A 2D: 0.5691, Ratio: 0.2295
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 5.3, Clustering F 2D: 0.3982, Clustering A 2D: 0.4150, Ratio: 0.9593
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 5.7, Modularity F 2D: 0.1240, Modularity A 2D: 0.5691, Ratio: 0.2178
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 5.7, Clustering F 2D: 0.5273, Clustering A 2D: 0.4150, Ratio: 1.2706
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 6.0, Modularity F 2D: 0.1259, Modularity A 2D: 0.5691, Ratio: 0.2212
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 6.0, Clustering F 2D: 0.5226, Clustering A 2D: 0.4150, Ratio: 1.2592
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 6.4, Modularity F 2D: 0.1477, Modularity A 2D: 0.5691, Ratio: 0.2596
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 6.4, Clustering F 2D: 0.4465, Clustering A 2D: 0.4150, Ratio: 1.0757
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 6.8, Modularity F 2D: 0.1284, Modularity A 2D: 0.5691, Ratio: 0.2256
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 6.8, Clustering F 2D: 0.4414, Clustering A 2D: 0.4150, Ratio: 1.0635
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 7.1, Modularity F 2D: 0.1353, Modularity A 2D: 0.5691, Ratio: 0.2377
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 7.1, Clustering F 2D: 0.3870, Clustering A 2D: 0.4150, Ratio: 0.9325
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 7.5, Modularity F 2D: 0.1413, Modularity A 2D: 0.5691, Ratio: 0.2483
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 7.5, Clustering F 2D: 0.3976, Clustering A 2D: 0.4150, Ratio: 0.9579
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 7.9, Modularity F 2D: 0.1649, Modularity A 2D: 0.5691, Ratio: 0.2898
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 7.9, Clustering F 2D: 0.3558, Clustering A 2D: 0.4150, Ratio: 0.8572
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 8.2, Modularity F 2D: 0.1796, Modularity A 2D: 0.5691, Ratio: 0.3157
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 8.2, Clustering F 2D: 0.3379, Clustering A 2D: 0.4150, Ratio: 0.8143
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 8.6, Modularity F 2D: 0.1879, Modularity A 2D: 0.5691, Ratio: 0.3302
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 8.6, Clustering F 2D: 0.3108, Clustering A 2D: 0.4150, Ratio: 0.7489
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 9.0, Modularity F 2D: 0.2228, Modularity A 2D: 0.5691, Ratio: 0.3915
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 9.0, Clustering F 2D: 0.2935, Clustering A 2D: 0.4150, Ratio: 0.7071
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 9.3, Modularity F 2D: 0.3751, Modularity A 2D: 0.5691, Ratio: 0.6592
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 9.3, Clustering F 2D: 0.4048, Clustering A 2D: 0.4150, Ratio: 0.9754
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 9.7, Modularity F 2D: 0.4358, Modularity A 2D: 0.5691, Ratio: 0.7658
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 9.7, Clustering F 2D: 0.4825, Clustering A 2D: 0.4150, Ratio: 1.1625
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 10.1, Modularity F 2D: 0.3964, Modularity A 2D: 0.5691, Ratio: 0.6966
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 10.1, Clustering F 2D: 0.5446, Clustering A 2D: 0.4150, Ratio: 1.3121
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 10.4, Modularity F 2D: 0.4628, Modularity A 2D: 0.5691, Ratio: 0.8133
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 10.4, Clustering F 2D: 0.5567, Clustering A 2D: 0.4150, Ratio: 1.3413
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 10.8, Modularity F 2D: 0.5303, Modularity A 2D: 0.5691, Ratio: 0.9318
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 10.8, Clustering F 2D: 0.5629, Clustering A 2D: 0.4150, Ratio: 1.3562
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 11.2, Modularity F 2D: 0.6215, Modularity A 2D: 0.5691, Ratio: 1.0922
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 11.2, Clustering F 2D: 0.6311, Clustering A 2D: 0.4150, Ratio: 1.5206
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 11.6, Modularity F 2D: 0.5741, Modularity A 2D: 0.5691, Ratio: 1.0089
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 11.6, Clustering F 2D: 0.5877, Clustering A 2D: 0.4150, Ratio: 1.4159
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 11.9, Modularity F 2D: 0.3779, Modularity A 2D: 0.5691, Ratio: 0.6640
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 11.9, Clustering F 2D: 0.5487, Clustering A 2D: 0.4150, Ratio: 1.3222
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 12.3, Modularity F 2D: 0.5274, Modularity A 2D: 0.5691, Ratio: 0.9267
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 12.3, Clustering F 2D: 0.5963, Clustering A 2D: 0.4150, Ratio: 1.4368
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 12.7, Modularity F 2D: 0.4813, Modularity A 2D: 0.5691, Ratio: 0.8458
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 12.7, Clustering F 2D: 0.5915, Clustering A 2D: 0.4150, Ratio: 1.4252
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 13.0, Modularity F 2D: 0.5243, Modularity A 2D: 0.5691, Ratio: 0.9213
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 13.0, Clustering F 2D: 0.6001, Clustering A 2D: 0.4150, Ratio: 1.4459
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 13.4, Modularity F 2D: 0.3837, Modularity A 2D: 0.5691, Ratio: 0.6743
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 13.4, Clustering F 2D: 0.5640, Clustering A 2D: 0.4150, Ratio: 1.3589
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 13.8, Modularity F 2D: 0.5358, Modularity A 2D: 0.5691, Ratio: 0.9416
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 13.8, Clustering F 2D: 0.5658, Clustering A 2D: 0.4150, Ratio: 1.3633
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 14.1, Modularity F 2D: 0.5584, Modularity A 2D: 0.5691, Ratio: 0.9812
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 14.1, Clustering F 2D: 0.5936, Clustering A 2D: 0.4150, Ratio: 1.4302
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 14.5, Modularity F 2D: 0.4806, Modularity A 2D: 0.5691, Ratio: 0.8445
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 14.5, Clustering F 2D: 0.5893, Clustering A 2D: 0.4150, Ratio: 1.4200
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 14.9, Modularity F 2D: 0.5017, Modularity A 2D: 0.5691, Ratio: 0.8815
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 14.9, Clustering F 2D: 0.5864, Clustering A 2D: 0.4150, Ratio: 1.4130
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 15.2, Modularity F 2D: 0.4906, Modularity A 2D: 0.5691, Ratio: 0.8620
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 15.2, Clustering F 2D: 0.5815, Clustering A 2D: 0.4150, Ratio: 1.4010
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 15.6, Modularity F 2D: 0.4505, Modularity A 2D: 0.5691, Ratio: 0.7917
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 15.6, Clustering F 2D: 0.5893, Clustering A 2D: 0.4150, Ratio: 1.4198
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 16.0, Modularity F 2D: 0.4530, Modularity A 2D: 0.5691, Ratio: 0.7961
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 16.0, Clustering F 2D: 0.5774, Clustering A 2D: 0.4150, Ratio: 1.3913
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 16.3, Modularity F 2D: 0.4706, Modularity A 2D: 0.5691, Ratio: 0.8270
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 16.3, Clustering F 2D: 0.5956, Clustering A 2D: 0.4150, Ratio: 1.4351
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 16.7, Modularity F 2D: 0.3926, Modularity A 2D: 0.5691, Ratio: 0.6899
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 16.7, Clustering F 2D: 0.5551, Clustering A 2D: 0.4150, Ratio: 1.3374
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 17.1, Modularity F 2D: 0.5550, Modularity A 2D: 0.5691, Ratio: 0.9753
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 17.1, Clustering F 2D: 0.5860, Clustering A 2D: 0.4150, Ratio: 1.4120
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 17.4, Modularity F 2D: 0.5397, Modularity A 2D: 0.5691, Ratio: 0.9483
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 17.4, Clustering F 2D: 0.5791, Clustering A 2D: 0.4150, Ratio: 1.3954
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 17.8, Modularity F 2D: 0.5620, Modularity A 2D: 0.5691, Ratio: 0.9877
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 17.8, Clustering F 2D: 0.5816, Clustering A 2D: 0.4150, Ratio: 1.4013
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 18.2, Modularity F 2D: 0.5809, Modularity A 2D: 0.5691, Ratio: 1.0207
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 18.2, Clustering F 2D: 0.6049, Clustering A 2D: 0.4150, Ratio: 1.4575
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 18.5, Modularity F 2D: 0.4966, Modularity A 2D: 0.5691, Ratio: 0.8726
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 18.5, Clustering F 2D: 0.5517, Clustering A 2D: 0.4150, Ratio: 1.3292
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 18.9, Modularity F 2D: 0.4915, Modularity A 2D: 0.5691, Ratio: 0.8638
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 18.9, Clustering F 2D: 0.5564, Clustering A 2D: 0.4150, Ratio: 1.3407
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 19.3, Modularity F 2D: 0.5534, Modularity A 2D: 0.5691, Ratio: 0.9724
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 19.3, Clustering F 2D: 0.5691, Clustering A 2D: 0.4150, Ratio: 1.3713
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 19.6, Modularity F 2D: 0.6460, Modularity A 2D: 0.5691, Ratio: 1.1352
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 19.6, Clustering F 2D: 0.6022, Clustering A 2D: 0.4150, Ratio: 1.4509
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 20.0, Modularity F 2D: 0.4591, Modularity A 2D: 0.5691, Ratio: 0.8067
# Sigma: 0.0622, Gini: 0.8394, Exc Weight: 20.0, Clustering F 2D: 0.5598, Clustering A 2D: 0.4150, Ratio: 1.3489
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 2.0, Modularity F 2D: 0.1224, Modularity A 2D: 0.4923, Ratio: 0.2486
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 2.0, Clustering F 2D: 0.4844, Clustering A 2D: 0.4128, Ratio: 1.1733
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 2.4, Modularity F 2D: 0.1138, Modularity A 2D: 0.4923, Ratio: 0.2312
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 2.4, Clustering F 2D: 0.4827, Clustering A 2D: 0.4128, Ratio: 1.1693
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 2.7, Modularity F 2D: 0.1358, Modularity A 2D: 0.4923, Ratio: 0.2759
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 2.7, Clustering F 2D: 0.4791, Clustering A 2D: 0.4128, Ratio: 1.1606
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 3.1, Modularity F 2D: 0.1191, Modularity A 2D: 0.4923, Ratio: 0.2419
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 3.1, Clustering F 2D: 0.4827, Clustering A 2D: 0.4128, Ratio: 1.1692
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 3.5, Modularity F 2D: 0.1408, Modularity A 2D: 0.4923, Ratio: 0.2860
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 3.5, Clustering F 2D: 0.4846, Clustering A 2D: 0.4128, Ratio: 1.1739
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 3.8, Modularity F 2D: 0.1417, Modularity A 2D: 0.4923, Ratio: 0.2878
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 3.8, Clustering F 2D: 0.4853, Clustering A 2D: 0.4128, Ratio: 1.1755
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 4.2, Modularity F 2D: 0.1321, Modularity A 2D: 0.4923, Ratio: 0.2683
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 4.2, Clustering F 2D: 0.4811, Clustering A 2D: 0.4128, Ratio: 1.1653
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 4.6, Modularity F 2D: 0.1282, Modularity A 2D: 0.4923, Ratio: 0.2604
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 4.6, Clustering F 2D: 0.4719, Clustering A 2D: 0.4128, Ratio: 1.1430
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 4.9, Modularity F 2D: 0.1269, Modularity A 2D: 0.4923, Ratio: 0.2577
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 4.9, Clustering F 2D: 0.4903, Clustering A 2D: 0.4128, Ratio: 1.1876
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 5.3, Modularity F 2D: 0.1269, Modularity A 2D: 0.4923, Ratio: 0.2578
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 5.3, Clustering F 2D: 0.4847, Clustering A 2D: 0.4128, Ratio: 1.1742
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 5.7, Modularity F 2D: 0.1353, Modularity A 2D: 0.4923, Ratio: 0.2748
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 5.7, Clustering F 2D: 0.3839, Clustering A 2D: 0.4128, Ratio: 0.9299
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 6.0, Modularity F 2D: 0.1462, Modularity A 2D: 0.4923, Ratio: 0.2970
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 6.0, Clustering F 2D: 0.3955, Clustering A 2D: 0.4128, Ratio: 0.9579
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 6.4, Modularity F 2D: 0.1314, Modularity A 2D: 0.4923, Ratio: 0.2669
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 6.4, Clustering F 2D: 0.4317, Clustering A 2D: 0.4128, Ratio: 1.0456
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 6.8, Modularity F 2D: 0.1406, Modularity A 2D: 0.4923, Ratio: 0.2855
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 6.8, Clustering F 2D: 0.4160, Clustering A 2D: 0.4128, Ratio: 1.0076
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 7.1, Modularity F 2D: 0.1384, Modularity A 2D: 0.4923, Ratio: 0.2811
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 7.1, Clustering F 2D: 0.4256, Clustering A 2D: 0.4128, Ratio: 1.0310
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 7.5, Modularity F 2D: 0.1476, Modularity A 2D: 0.4923, Ratio: 0.2999
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 7.5, Clustering F 2D: 0.4134, Clustering A 2D: 0.4128, Ratio: 1.0013
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 7.9, Modularity F 2D: 0.1720, Modularity A 2D: 0.4923, Ratio: 0.3493
# Sigma: 0.0671, Gini: 0.8292, Exc Weight: 7.9, Clustering F 2D: 0.3519, Clustering A 2D: 0.4128, Ratio: 0.8523
# ...
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 7.9, Clustering F 2D: 0.3795, Clustering A 2D: 0.3770, Ratio: 1.0066
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 8.2, Modularity F 2D: 0.2376, Modularity A 2D: 0.5672, Ratio: 0.4188
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 8.2, Clustering F 2D: 0.3532, Clustering A 2D: 0.3770, Ratio: 0.9369
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 8.6, Modularity F 2D: 0.2289, Modularity A 2D: 0.5672, Ratio: 0.4035
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 8.6, Clustering F 2D: 0.3507, Clustering A 2D: 0.3770, Ratio: 0.9304
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 9.0, Modularity F 2D: 0.1852, Modularity A 2D: 0.5672, Ratio: 0.3264
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 9.0, Clustering F 2D: 0.3010, Clustering A 2D: 0.3770, Ratio: 0.7985
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 9.3, Modularity F 2D: 0.2493, Modularity A 2D: 0.5672, Ratio: 0.4395
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 9.3, Clustering F 2D: 0.3039, Clustering A 2D: 0.3770, Ratio: 0.8061
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 9.7, Modularity F 2D: 0.3738, Modularity A 2D: 0.5672, Ratio: 0.6590
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 9.7, Clustering F 2D: 0.3565, Clustering A 2D: 0.3770, Ratio: 0.9458
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 10.1, Modularity F 2D: 0.3590, Modularity A 2D: 0.5672, Ratio: 0.6328
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 10.1, Clustering F 2D: 0.3430, Clustering A 2D: 0.3770, Ratio: 0.9100
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 10.4, Modularity F 2D: 0.3458, Modularity A 2D: 0.5672, Ratio: 0.6096
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 10.4, Clustering F 2D: 0.5067, Clustering A 2D: 0.3770, Ratio: 1.3442
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 10.8, Modularity F 2D: 0.5543, Modularity A 2D: 0.5672, Ratio: 0.9771
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 10.8, Clustering F 2D: 0.5449, Clustering A 2D: 0.3770, Ratio: 1.4455
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 11.2, Modularity F 2D: 0.5306, Modularity A 2D: 0.5672, Ratio: 0.9354
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 11.2, Clustering F 2D: 0.5874, Clustering A 2D: 0.3770, Ratio: 1.5584
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 11.6, Modularity F 2D: 0.5775, Modularity A 2D: 0.5672, Ratio: 1.0181
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 11.6, Clustering F 2D: 0.5894, Clustering A 2D: 0.3770, Ratio: 1.5635
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 11.9, Modularity F 2D: 0.5484, Modularity A 2D: 0.5672, Ratio: 0.9667
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 11.9, Clustering F 2D: 0.6112, Clustering A 2D: 0.3770, Ratio: 1.6215
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 12.3, Modularity F 2D: 0.6288, Modularity A 2D: 0.5672, Ratio: 1.1085
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 12.3, Clustering F 2D: 0.6248, Clustering A 2D: 0.3770, Ratio: 1.6574
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 12.7, Modularity F 2D: 0.5511, Modularity A 2D: 0.5672, Ratio: 0.9715
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 12.7, Clustering F 2D: 0.5888, Clustering A 2D: 0.3770, Ratio: 1.5620
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 13.0, Modularity F 2D: 0.4895, Modularity A 2D: 0.5672, Ratio: 0.8630
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 13.0, Clustering F 2D: 0.5744, Clustering A 2D: 0.3770, Ratio: 1.5238
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 13.4, Modularity F 2D: 0.6065, Modularity A 2D: 0.5672, Ratio: 1.0692
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 13.4, Clustering F 2D: 0.5880, Clustering A 2D: 0.3770, Ratio: 1.5599
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 13.8, Modularity F 2D: 0.5525, Modularity A 2D: 0.5672, Ratio: 0.9741
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 13.8, Clustering F 2D: 0.5687, Clustering A 2D: 0.3770, Ratio: 1.5087
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 14.1, Modularity F 2D: 0.5871, Modularity A 2D: 0.5672, Ratio: 1.0350
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 14.1, Clustering F 2D: 0.5947, Clustering A 2D: 0.3770, Ratio: 1.5776
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 14.5, Modularity F 2D: 0.4917, Modularity A 2D: 0.5672, Ratio: 0.8668
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 14.5, Clustering F 2D: 0.5754, Clustering A 2D: 0.3770, Ratio: 1.5263
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 14.9, Modularity F 2D: 0.4390, Modularity A 2D: 0.5672, Ratio: 0.7739
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 14.9, Clustering F 2D: 0.5723, Clustering A 2D: 0.3770, Ratio: 1.5181
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 15.2, Modularity F 2D: 0.5192, Modularity A 2D: 0.5672, Ratio: 0.9153
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 15.2, Clustering F 2D: 0.5564, Clustering A 2D: 0.3770, Ratio: 1.4761
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 15.6, Modularity F 2D: 0.5161, Modularity A 2D: 0.5672, Ratio: 0.9098
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 15.6, Clustering F 2D: 0.5732, Clustering A 2D: 0.3770, Ratio: 1.5207
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 16.0, Modularity F 2D: 0.4882, Modularity A 2D: 0.5672, Ratio: 0.8607
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 16.0, Clustering F 2D: 0.5517, Clustering A 2D: 0.3770, Ratio: 1.4636
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 16.3, Modularity F 2D: 0.4388, Modularity A 2D: 0.5672, Ratio: 0.7735
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 16.3, Clustering F 2D: 0.5561, Clustering A 2D: 0.3770, Ratio: 1.4753
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 16.7, Modularity F 2D: 0.4236, Modularity A 2D: 0.5672, Ratio: 0.7468
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 16.7, Clustering F 2D: 0.5519, Clustering A 2D: 0.3770, Ratio: 1.4641
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 17.1, Modularity F 2D: 0.5015, Modularity A 2D: 0.5672, Ratio: 0.8841
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 17.1, Clustering F 2D: 0.5755, Clustering A 2D: 0.3770, Ratio: 1.5266
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 17.4, Modularity F 2D: 0.5512, Modularity A 2D: 0.5672, Ratio: 0.9718
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 17.4, Clustering F 2D: 0.5574, Clustering A 2D: 0.3770, Ratio: 1.4786
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 17.8, Modularity F 2D: 0.5293, Modularity A 2D: 0.5672, Ratio: 0.9331
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 17.8, Clustering F 2D: 0.5650, Clustering A 2D: 0.3770, Ratio: 1.4988
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 18.2, Modularity F 2D: 0.5225, Modularity A 2D: 0.5672, Ratio: 0.9211
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 18.2, Clustering F 2D: 0.5721, Clustering A 2D: 0.3770, Ratio: 1.5177
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 18.5, Modularity F 2D: 0.4462, Modularity A 2D: 0.5672, Ratio: 0.7866
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 18.5, Clustering F 2D: 0.5541, Clustering A 2D: 0.3770, Ratio: 1.4698
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 18.9, Modularity F 2D: 0.5521, Modularity A 2D: 0.5672, Ratio: 0.9733
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 18.9, Clustering F 2D: 0.5506, Clustering A 2D: 0.3770, Ratio: 1.4607
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 19.3, Modularity F 2D: 0.4838, Modularity A 2D: 0.5672, Ratio: 0.8529
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 19.3, Clustering F 2D: 0.5600, Clustering A 2D: 0.3770, Ratio: 1.4856
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 19.6, Modularity F 2D: 0.4479, Modularity A 2D: 0.5672, Ratio: 0.7896
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 19.6, Clustering F 2D: 0.5405, Clustering A 2D: 0.3770, Ratio: 1.4337
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 20.0, Modularity F 2D: 0.5236, Modularity A 2D: 0.5672, Ratio: 0.9230
# Sigma: 0.0858, Gini: 0.7884, Exc Weight: 20.0, Clustering F 2D: 0.5560, Clustering A 2D: 0.3770, Ratio: 1.4751
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 2.0, Modularity F 2D: 0.1196, Modularity A 2D: 0.4763, Ratio: 0.2511
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 2.0, Clustering F 2D: 0.4211, Clustering A 2D: 0.3578, Ratio: 1.1769
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 2.4, Modularity F 2D: 0.1260, Modularity A 2D: 0.4763, Ratio: 0.2645
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 2.4, Clustering F 2D: 0.4107, Clustering A 2D: 0.3578, Ratio: 1.1477
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 2.7, Modularity F 2D: 0.1281, Modularity A 2D: 0.4763, Ratio: 0.2690
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 2.7, Clustering F 2D: 0.4013, Clustering A 2D: 0.3578, Ratio: 1.1214
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 3.1, Modularity F 2D: 0.1301, Modularity A 2D: 0.4763, Ratio: 0.2731
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 3.1, Clustering F 2D: 0.4029, Clustering A 2D: 0.3578, Ratio: 1.1259
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 3.5, Modularity F 2D: 0.1322, Modularity A 2D: 0.4763, Ratio: 0.2776
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 3.5, Clustering F 2D: 0.4588, Clustering A 2D: 0.3578, Ratio: 1.2822
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 3.8, Modularity F 2D: 0.1257, Modularity A 2D: 0.4763, Ratio: 0.2639
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 3.8, Clustering F 2D: 0.4616, Clustering A 2D: 0.3578, Ratio: 1.2901
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 4.2, Modularity F 2D: 0.1368, Modularity A 2D: 0.4763, Ratio: 0.2873
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 4.2, Clustering F 2D: 0.4835, Clustering A 2D: 0.3578, Ratio: 1.3511
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 4.6, Modularity F 2D: 0.1235, Modularity A 2D: 0.4763, Ratio: 0.2594
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 4.6, Clustering F 2D: 0.4664, Clustering A 2D: 0.3578, Ratio: 1.3035
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 4.9, Modularity F 2D: 0.1223, Modularity A 2D: 0.4763, Ratio: 0.2568
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 4.9, Clustering F 2D: 0.4629, Clustering A 2D: 0.3578, Ratio: 1.2935
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 5.3, Modularity F 2D: 0.1275, Modularity A 2D: 0.4763, Ratio: 0.2677
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 5.3, Clustering F 2D: 0.4275, Clustering A 2D: 0.3578, Ratio: 1.1948
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 5.7, Modularity F 2D: 0.1356, Modularity A 2D: 0.4763, Ratio: 0.2847
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 5.7, Clustering F 2D: 0.4194, Clustering A 2D: 0.3578, Ratio: 1.1721
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 6.0, Modularity F 2D: 0.1407, Modularity A 2D: 0.4763, Ratio: 0.2955
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 6.0, Clustering F 2D: 0.4511, Clustering A 2D: 0.3578, Ratio: 1.2608
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 6.4, Modularity F 2D: 0.1341, Modularity A 2D: 0.4763, Ratio: 0.2816
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 6.4, Clustering F 2D: 0.4198, Clustering A 2D: 0.3578, Ratio: 1.1733
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 6.8, Modularity F 2D: 0.1428, Modularity A 2D: 0.4763, Ratio: 0.2998
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 6.8, Clustering F 2D: 0.3994, Clustering A 2D: 0.3578, Ratio: 1.1163
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 7.1, Modularity F 2D: 0.1442, Modularity A 2D: 0.4763, Ratio: 0.3028
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 7.1, Clustering F 2D: 0.3729, Clustering A 2D: 0.3578, Ratio: 1.0420
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 7.5, Modularity F 2D: 0.1617, Modularity A 2D: 0.4763, Ratio: 0.3394
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 7.5, Clustering F 2D: 0.3724, Clustering A 2D: 0.3578, Ratio: 1.0406
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 7.9, Modularity F 2D: 0.1478, Modularity A 2D: 0.4763, Ratio: 0.3104
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 7.9, Clustering F 2D: 0.3427, Clustering A 2D: 0.3578, Ratio: 0.9576
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 8.2, Modularity F 2D: 0.1526, Modularity A 2D: 0.4763, Ratio: 0.3204
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 8.2, Clustering F 2D: 0.3341, Clustering A 2D: 0.3578, Ratio: 0.9337
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 8.6, Modularity F 2D: 0.1957, Modularity A 2D: 0.4763, Ratio: 0.4109
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 8.6, Clustering F 2D: 0.3022, Clustering A 2D: 0.3578, Ratio: 0.8445
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 9.0, Modularity F 2D: 0.2647, Modularity A 2D: 0.4763, Ratio: 0.5559
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 9.0, Clustering F 2D: 0.3077, Clustering A 2D: 0.3578, Ratio: 0.8600
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 9.3, Modularity F 2D: 0.2529, Modularity A 2D: 0.4763, Ratio: 0.5310
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 9.3, Clustering F 2D: 0.3065, Clustering A 2D: 0.3578, Ratio: 0.8566
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 9.7, Modularity F 2D: 0.2709, Modularity A 2D: 0.4763, Ratio: 0.5688
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 9.7, Clustering F 2D: 0.2949, Clustering A 2D: 0.3578, Ratio: 0.8241
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 10.1, Modularity F 2D: 0.2969, Modularity A 2D: 0.4763, Ratio: 0.6234
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 10.1, Clustering F 2D: 0.4461, Clustering A 2D: 0.3578, Ratio: 1.2467
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 10.4, Modularity F 2D: 0.3951, Modularity A 2D: 0.4763, Ratio: 0.8295
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 10.4, Clustering F 2D: 0.4869, Clustering A 2D: 0.3578, Ratio: 1.3608
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 10.8, Modularity F 2D: 0.4007, Modularity A 2D: 0.4763, Ratio: 0.8413
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 10.8, Clustering F 2D: 0.5137, Clustering A 2D: 0.3578, Ratio: 1.4356
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 11.2, Modularity F 2D: 0.3926, Modularity A 2D: 0.4763, Ratio: 0.8244
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 11.2, Clustering F 2D: 0.5524, Clustering A 2D: 0.3578, Ratio: 1.5438
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 11.6, Modularity F 2D: 0.2569, Modularity A 2D: 0.4763, Ratio: 0.5394
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 11.6, Clustering F 2D: 0.5407, Clustering A 2D: 0.3578, Ratio: 1.5111
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 11.9, Modularity F 2D: 0.2456, Modularity A 2D: 0.4763, Ratio: 0.5156
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 11.9, Clustering F 2D: 0.5410, Clustering A 2D: 0.3578, Ratio: 1.5120
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 12.3, Modularity F 2D: 0.3873, Modularity A 2D: 0.4763, Ratio: 0.8133
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 12.3, Clustering F 2D: 0.5092, Clustering A 2D: 0.3578, Ratio: 1.4229
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 12.7, Modularity F 2D: 0.2870, Modularity A 2D: 0.4763, Ratio: 0.6025
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 12.7, Clustering F 2D: 0.5256, Clustering A 2D: 0.3578, Ratio: 1.4689
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 13.0, Modularity F 2D: 0.1745, Modularity A 2D: 0.4763, Ratio: 0.3664
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 13.0, Clustering F 2D: 0.5338, Clustering A 2D: 0.3578, Ratio: 1.4917
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 13.4, Modularity F 2D: 0.2824, Modularity A 2D: 0.4763, Ratio: 0.5930
# Sigma: 0.0904, Gini: 0.7782, Exc Weight: 13.4, Clustering F 2D: 0.4958, Clustering A 2D: 0.3578, Ratio: 1.3857
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 62
#      59     print(f"Archivo no encontrado para sigma={sigma:.4f}, exc_weight={exc_weight:.1f}")
#      60     continue
# ---> 62 F, F_binary, F_ordered, order, communities = fcn.build_F_matrix(filename_dyn_2D, SIM_TIME = 10000, N = A_2D.shape[0])
#      63 F_binary = ((F_binary + F_binary.T) > 0).astype(int)  # Ensure the functional connectivity matrix is symmetric and binary
#      64 modularity_F_2D = louvain_modularity(F_binary)
#
# File c:\Users\Admin\Desktop\Master\TFM\functions_create_networks.py:2028, in build_F_matrix(filename_dynamics, SIM_TIME, N)
#    2027 def build_F_matrix(filename_dynamics, SIM_TIME=5000, N=1000):
# -> 2028     M, times = build_temporal_neuron_series(
#    2029         filename_dynamics,
#    2030         time_window=25,
#    2031         SIM_TIME=SIM_TIME,
#    2032         N=N
#    2033     )
#    2035     firings_t, firings_i = np.loadtxt(filename_dynamics, skiprows=1, unpack=True)
#    2036     firings_t, firings_i = load_firings(filename_dynamics)
#
# File c:\Users\Admin\Desktop\Master\TFM\functions_create_networks.py:1374, in build_temporal_neuron_series(filename, time_window, SIM_TIME, N)
#    1371     if row >= len(times):
#    1372         continue
# -> 1374     M[row, col] = 1
#    1376 return M, times
#
# KeyboardInterrupt:

# %%
import pandas as pd
from functools import reduce

# =========================
# LIST OF FILES
# =========================

sims = 7
filenames = [f"figures_TFM/data_for_figures/clustering_map_2D_sim_{i}.txt" for i in range(sims)]

# =========================
# LOAD ALL FILES
# =========================

dfs = [pd.read_csv(f, sep=r"\s+") for f in filenames]

# =========================
# COLUMNS THAT IDENTIFY EACH POINT
# =========================

keys = ["sigma", "gini", "exc_weight"]

# =========================
# NUMERICAL COLUMNS TO AVERAGE
# =========================

value_columns = [col for col in dfs[0].columns if col not in keys]

# =========================
# MERGE ALL DATAFRAMES
# =========================

merged = dfs[0]

for i, df in enumerate(dfs[1:], start=1):

    renamed = df.rename(
        columns={
            col: f"{col}_{i}"
            for col in value_columns
        }
    )

    merged = pd.merge(
        merged,
        renamed,
        on=keys
    )

# =========================
# COMPUTE MEANS
# =========================

result = merged[keys].copy()

for col in value_columns:

    cols_to_average = [col] + [f"{col}_{i}" for i in range(1, len(dfs))]

    result[col] = merged[cols_to_average].mean(axis=1)

# =========================
# SAVE OUTPUT
# =========================

output_filename = "figures_TFM/data_for_figures/clustering_map_2D_average.txt"

result.to_csv(
    output_filename,
    sep="\t",
    index=False,
    float_format="%.4f"
)

print(f"Saved averaged file to: {output_filename}")
# Out:
# Saved averaged file to: figures_TFM/data_for_figures/clustering_map_2D_average.txt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

map_modularity = "figures_TFM/data_for_figures/modularity_map_2D_average.txt"

df = pd.read_csv(map_modularity, sep=r"\s+")

# Matriz: filas = excitación, columnas = Gini
pivot = df.pivot_table(
    index="exc_weight",
    columns="gini",
    values="modF/modA",
    aggfunc="mean"
).sort_index().sort_index(axis=1)

x = pivot.columns.to_numpy(dtype=float)      # Gini
y = pivot.index.to_numpy(dtype=float)        # Excitatory weight
Z = pivot.to_numpy(dtype=float)

# Suavizado opcional
Z = gaussian_filter(Z, sigma=0.01)
Z_diff = np.abs(1-Z)

X, Y = np.meshgrid(x, y)

fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(
    Z_diff,
    origin="lower",
    aspect="auto",
    extent=[x.min(), x.max(), y.min(), y.max()],
    cmap="viridis_r", 
    # interpolation="bilinear"
)

# contours = ax.contour(
#     X, Y, Z_smooth,
#     levels=[0.2, 0.5, 0.9],
#     colors="white",
#     linewidths=2
# )

# ax.clabel(
#     contours,
#     inline=True,
#     fontsize=13,
#     fmt="%.2f",
#     colors="white"
# )

ax.set_xlabel(r"$\Lambda$", fontsize=20)
ax.set_ylabel(r"$E$", fontsize=20)

ax.tick_params(labelsize=18)

# Título estilo imagen
# ax.text(
#     0.02, 1.02, "A) 2D",
#     transform=ax.transAxes,
#     fontsize=20,
#     ha="left",
#     va="bottom"
# )

cbar = plt.colorbar(im, ax=ax, pad=0.02)
cbar.set_label(
    r"$|1-Q_F/Q_A|$",
    fontsize=15
)
cbar.ax.tick_params(labelsize=18)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

vmin = np.min(Z)
vmax = np.max(Z)

fig, ax = plt.subplots(figsize=(0.5, 5))

norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = mpl.cm.ScalarMappable(norm=norm, cmap="viridis")
sm.set_array([])

cbar = plt.colorbar(sm, cax=ax)

cbar.set_label(r"$Q_A$", fontsize=18)
cbar.ax.tick_params(labelsize=16)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

map_clustering = "figures_TFM/data_for_figures/clustering_map_2D_average.txt"
cmapC = load_cmap("lapaz", cmap_type="continuous")
df = pd.read_csv(map_clustering, sep=r"\s+")

# Matriz: filas = excitación, columnas = Gini
pivot = df.pivot_table(
    index="exc_weight",
    columns="gini",
    values="clusF/clusA",
    aggfunc="mean"
).sort_index().sort_index(axis=1)

x = pivot.columns.to_numpy(dtype=float)      # Gini
y = pivot.index.to_numpy(dtype=float)        # Excitatory weight
Z = pivot.to_numpy(dtype=float)

# Suavizado opcional
Z = gaussian_filter(Z, sigma=2)
Z_diff = np.abs(1-Z)

X, Y = np.meshgrid(x, y)

fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(
    Z_diff,
    origin="lower",
    aspect="auto",
    extent=[x.min(), x.max(), y.min(), y.max()],
    cmap=cmapC, 
    interpolation="bilinear"
)

# contours = ax.contour(
#     X, Y, Z_smooth,
#     levels=[0.2, 0.5, 0.9],
#     colors="white",
#     linewidths=2
# )

# ax.clabel(
#     contours,
#     inline=True,
#     fontsize=13,
#     fmt="%.2f",
#     colors="white"
# )

ax.set_xlabel(r"$\Lambda$", fontsize=20)
ax.set_ylabel(r"$E$", fontsize=20)

ax.tick_params(labelsize=14)

# Título estilo imagen
# ax.text(
#     # 0.02, 1.02, "A) 2D",
#     transform=ax.transAxes,
#     fontsize=20,
#     ha="left",
#     va="bottom"
# )

cbar = plt.colorbar(im, ax=ax, pad=0.02)
cbar.set_label(
    r"$|1-C_{F}/C_{S}|$",
    fontsize=15
)
cbar.ax.tick_params(labelsize=18)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

vmin = np.min(Z)
vmax = np.max(Z)

fig, ax = plt.subplots(figsize=(0.5, 5))

norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = mpl.cm.ScalarMappable(norm=norm, cmap="viridis")
sm.set_array([])

cbar = plt.colorbar(sm, cax=ax)

cbar.set_label(r"$C_A$", fontsize=18)
cbar.ax.tick_params(labelsize=16)

plt.show()

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

calibration_filename = "figures_TFM/data_for_figures/gini3D_n_grid13_calibration.txt"
data = np.loadtxt(calibration_filename, skiprows=1)
gini_values = data[:,0]
base_sigma_values = data[:,1]

MAX_EXC_WEIGHT_values = np.linspace(2, 20.0, 50)

def louvain_modularity(A):
    import networkx as nx

    G = nx.from_numpy_array(A)

    if G.number_of_edges() == 0:
        return np.nan

    communities = nx.community.louvain_communities(G, seed=0)
    modularity = nx.community.modularity(G, communities)

    return modularity

def compute_clustering_coefficient(A):
    import networkx as nx

    G = nx.from_numpy_array(A)

    if G.number_of_edges() == 0:
        return np.nan

    clustering_coeffs = nx.clustering(G)
    average_clustering = np.mean(list(clustering_coeffs.values()))

    return average_clustering

out_filename_mod = "figures_TFM/data_for_figures/modularity_map_3D.txt"
out_filename_clust = "figures_TFM/data_for_figures/clustering_map_3D.txt"

with open(out_filename_mod, "w") as f:
    f.write("sigma\texc_weight\tmodF\tmodA\tmodF/modA\n")
with open(out_filename_clust, "w") as f:
    f.write("sigma\texc_weight\tclusF\tclusA\tclusF/clusA\n")
k = 0
for sigma in base_sigma_values:
    gini = gini_values[k]
    filename_adj_3D, _= find_filename3D(sigma=sigma)
    if not os.path.exists(filename_adj_3D):
        print(f"Archivo no encontrado para sigma={sigma:.4f}")
        continue
    A_3D = fcn.load_A(filename_adj_3D)
    A_3D = ((A_3D + A_3D.T) > 0).astype(int)  # Ensure the adjacency matrix is symmetric and binary
    modularity_3D = louvain_modularity(A_3D)
    # clustering_3D = compute_clustering_coefficient(A_3D)
    for exc_weight in MAX_EXC_WEIGHT_values:

        _, filename_dyn_3D = find_filename3D(sigma=sigma, exc_weight=exc_weight)
        if not os.path.exists(filename_dyn_3D):
            print(f"Archivo no encontrado para sigma={sigma:.4f}, exc_weight={exc_weight:.1f}")
            continue

        F, F_binary, F_ordered, order, communities = fcn.build_F_matrix(filename_dyn_3D, SIM_TIME = 10000, N = A_3D.shape[0])
        F_binary = ((F_binary + F_binary.T) > 0).astype(int)  # Ensure the functional connectivity matrix is symmetric and binary
        modularity_F_3D = louvain_modularity(F_binary)
        # clustering_F_3D = compute_clustering_coefficient(F_binary)
        modularity_ratio_3D = modularity_F_3D / modularity_3D if modularity_3D != 0 else np.nan

        print(f"Sigma: {sigma:.4f}, Gini: {gini:.4f}, Exc Weight: {exc_weight:.1f}, Modularity F 3D: {modularity_F_3D:.4f}, Modularity 3D: {modularity_3D:.4f}, Ratio: {modularity_ratio_3D:.4f}")
        # print(f"Sigma: {sigma:.4f}, Gini: {gini:.4f}, Exc Weight: {exc_weight:.1f}, Clustering F 3D: {clustering_F_3D:.4f}, Clustering 3D: {clustering_3D:.4f}, Ratio: {clustering_F_3D/clustering_3D:.4f}")

        with open(out_filename_mod, "a") as f:
            f.write(f"{sigma:.4f}\t{gini:.4f}\t{exc_weight:.1f}\t{modularity_F_3D:.4f}\t{modularity_3D:.4f}\t{modularity_ratio_3D:.4f}\n")
            # with open(out_filename_clust, "a") as f:
            #     f.write(f"{sigma:.4f}\t{gini:.4f}\t{exc_weight:.1f}\t{clustering_F_3D:.4f}\t{clustering_3D:.4f}\t{clustering_F_3D/clustering_3D:.4f}\n")
    k += 1
# Out:
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 2.0, Modularity F 3D: 0.1206, Modularity 3D: 0.7945, Ratio: 0.1517
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 2.4, Modularity F 3D: 0.1185, Modularity 3D: 0.7945, Ratio: 0.1491
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 2.7, Modularity F 3D: 0.1192, Modularity 3D: 0.7945, Ratio: 0.1500
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 3.1, Modularity F 3D: 0.1158, Modularity 3D: 0.7945, Ratio: 0.1457
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 3.5, Modularity F 3D: 0.1049, Modularity 3D: 0.7945, Ratio: 0.1320
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 3.8, Modularity F 3D: 0.1009, Modularity 3D: 0.7945, Ratio: 0.1270
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 4.2, Modularity F 3D: 0.1046, Modularity 3D: 0.7945, Ratio: 0.1317
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 4.6, Modularity F 3D: 0.1102, Modularity 3D: 0.7945, Ratio: 0.1387
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 4.9, Modularity F 3D: 0.0801, Modularity 3D: 0.7945, Ratio: 0.1009
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 5.3, Modularity F 3D: 0.0677, Modularity 3D: 0.7945, Ratio: 0.0852
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 5.7, Modularity F 3D: 0.0798, Modularity 3D: 0.7945, Ratio: 0.1005
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 6.0, Modularity F 3D: 0.3522, Modularity 3D: 0.7945, Ratio: 0.4433
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 6.4, Modularity F 3D: 0.4844, Modularity 3D: 0.7945, Ratio: 0.6097
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 6.8, Modularity F 3D: 0.4909, Modularity 3D: 0.7945, Ratio: 0.6179
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 7.1, Modularity F 3D: 0.4537, Modularity 3D: 0.7945, Ratio: 0.5711
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 7.5, Modularity F 3D: 0.4234, Modularity 3D: 0.7945, Ratio: 0.5329
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 7.9, Modularity F 3D: 0.4918, Modularity 3D: 0.7945, Ratio: 0.6190
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 8.2, Modularity F 3D: 0.4972, Modularity 3D: 0.7945, Ratio: 0.6259
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 8.6, Modularity F 3D: 0.4973, Modularity 3D: 0.7945, Ratio: 0.6260
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 9.0, Modularity F 3D: 0.4969, Modularity 3D: 0.7945, Ratio: 0.6255
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 9.3, Modularity F 3D: 0.4390, Modularity 3D: 0.7945, Ratio: 0.5526
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 9.7, Modularity F 3D: 0.4221, Modularity 3D: 0.7945, Ratio: 0.5313
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 10.1, Modularity F 3D: 0.4850, Modularity 3D: 0.7945, Ratio: 0.6105
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 10.4, Modularity F 3D: 0.4280, Modularity 3D: 0.7945, Ratio: 0.5387
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 10.8, Modularity F 3D: 0.4754, Modularity 3D: 0.7945, Ratio: 0.5983
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 11.2, Modularity F 3D: 0.5330, Modularity 3D: 0.7945, Ratio: 0.6710
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 11.6, Modularity F 3D: 0.4164, Modularity 3D: 0.7945, Ratio: 0.5241
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 11.9, Modularity F 3D: 0.4350, Modularity 3D: 0.7945, Ratio: 0.5476
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 12.3, Modularity F 3D: 0.4066, Modularity 3D: 0.7945, Ratio: 0.5118
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 12.7, Modularity F 3D: 0.5817, Modularity 3D: 0.7945, Ratio: 0.7322
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 13.0, Modularity F 3D: 0.4738, Modularity 3D: 0.7945, Ratio: 0.5964
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 13.4, Modularity F 3D: 0.5656, Modularity 3D: 0.7945, Ratio: 0.7120
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 13.8, Modularity F 3D: 0.5234, Modularity 3D: 0.7945, Ratio: 0.6589
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 14.1, Modularity F 3D: 0.5639, Modularity 3D: 0.7945, Ratio: 0.7098
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 14.5, Modularity F 3D: 0.5662, Modularity 3D: 0.7945, Ratio: 0.7127
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 14.9, Modularity F 3D: 0.5522, Modularity 3D: 0.7945, Ratio: 0.6951
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 15.2, Modularity F 3D: 0.4342, Modularity 3D: 0.7945, Ratio: 0.5466
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 15.6, Modularity F 3D: 0.4598, Modularity 3D: 0.7945, Ratio: 0.5787
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 16.0, Modularity F 3D: 0.5532, Modularity 3D: 0.7945, Ratio: 0.6963
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 16.3, Modularity F 3D: 0.4929, Modularity 3D: 0.7945, Ratio: 0.6204
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 16.7, Modularity F 3D: 0.5259, Modularity 3D: 0.7945, Ratio: 0.6620
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 17.1, Modularity F 3D: 0.5311, Modularity 3D: 0.7945, Ratio: 0.6686
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 17.4, Modularity F 3D: 0.5709, Modularity 3D: 0.7945, Ratio: 0.7186
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 17.8, Modularity F 3D: 0.5267, Modularity 3D: 0.7945, Ratio: 0.6629
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 18.2, Modularity F 3D: 0.4468, Modularity 3D: 0.7945, Ratio: 0.5624
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 18.5, Modularity F 3D: 0.5162, Modularity 3D: 0.7945, Ratio: 0.6498
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 18.9, Modularity F 3D: 0.4778, Modularity 3D: 0.7945, Ratio: 0.6014
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 19.3, Modularity F 3D: 0.4613, Modularity 3D: 0.7945, Ratio: 0.5806
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 19.6, Modularity F 3D: 0.4877, Modularity 3D: 0.7945, Ratio: 0.6139
# Sigma: 0.0317, Gini: 0.8450, Exc Weight: 20.0, Modularity F 3D: 0.4678, Modularity 3D: 0.7945, Ratio: 0.5889
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 2.0, Modularity F 3D: 0.1231, Modularity 3D: 0.7828, Ratio: 0.1573
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 2.4, Modularity F 3D: 0.1210, Modularity 3D: 0.7828, Ratio: 0.1545
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 2.7, Modularity F 3D: 0.1200, Modularity 3D: 0.7828, Ratio: 0.1533
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 3.1, Modularity F 3D: 0.1168, Modularity 3D: 0.7828, Ratio: 0.1493
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 3.5, Modularity F 3D: 0.0889, Modularity 3D: 0.7828, Ratio: 0.1135
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 3.8, Modularity F 3D: 0.1052, Modularity 3D: 0.7828, Ratio: 0.1344
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 4.2, Modularity F 3D: 0.1121, Modularity 3D: 0.7828, Ratio: 0.1432
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 4.6, Modularity F 3D: 0.0875, Modularity 3D: 0.7828, Ratio: 0.1118
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 4.9, Modularity F 3D: 0.0853, Modularity 3D: 0.7828, Ratio: 0.1090
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 5.3, Modularity F 3D: 0.0817, Modularity 3D: 0.7828, Ratio: 0.1044
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 5.7, Modularity F 3D: 0.0730, Modularity 3D: 0.7828, Ratio: 0.0933
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 6.0, Modularity F 3D: 0.0901, Modularity 3D: 0.7828, Ratio: 0.1151
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 6.4, Modularity F 3D: 0.0999, Modularity 3D: 0.7828, Ratio: 0.1276
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 6.8, Modularity F 3D: 0.2932, Modularity 3D: 0.7828, Ratio: 0.3745
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 7.1, Modularity F 3D: 0.4152, Modularity 3D: 0.7828, Ratio: 0.5304
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 7.5, Modularity F 3D: 0.4728, Modularity 3D: 0.7828, Ratio: 0.6040
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 7.9, Modularity F 3D: 0.4360, Modularity 3D: 0.7828, Ratio: 0.5570
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 8.2, Modularity F 3D: 0.5093, Modularity 3D: 0.7828, Ratio: 0.6506
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 8.6, Modularity F 3D: 0.5566, Modularity 3D: 0.7828, Ratio: 0.7111
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 9.0, Modularity F 3D: 0.4540, Modularity 3D: 0.7828, Ratio: 0.5800
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 9.3, Modularity F 3D: 0.5150, Modularity 3D: 0.7828, Ratio: 0.6579
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 9.7, Modularity F 3D: 0.5263, Modularity 3D: 0.7828, Ratio: 0.6723
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 10.1, Modularity F 3D: 0.4987, Modularity 3D: 0.7828, Ratio: 0.6370
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 10.4, Modularity F 3D: 0.5187, Modularity 3D: 0.7828, Ratio: 0.6626
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 10.8, Modularity F 3D: 0.5212, Modularity 3D: 0.7828, Ratio: 0.6658
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 11.2, Modularity F 3D: 0.4497, Modularity 3D: 0.7828, Ratio: 0.5745
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 11.6, Modularity F 3D: 0.5123, Modularity 3D: 0.7828, Ratio: 0.6544
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 11.9, Modularity F 3D: 0.4864, Modularity 3D: 0.7828, Ratio: 0.6214
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 12.3, Modularity F 3D: 0.4091, Modularity 3D: 0.7828, Ratio: 0.5226
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 12.7, Modularity F 3D: 0.5120, Modularity 3D: 0.7828, Ratio: 0.6541
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 13.0, Modularity F 3D: 0.4349, Modularity 3D: 0.7828, Ratio: 0.5555
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 13.4, Modularity F 3D: 0.4261, Modularity 3D: 0.7828, Ratio: 0.5443
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 13.8, Modularity F 3D: 0.4629, Modularity 3D: 0.7828, Ratio: 0.5913
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 14.1, Modularity F 3D: 0.4229, Modularity 3D: 0.7828, Ratio: 0.5402
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 14.5, Modularity F 3D: 0.5567, Modularity 3D: 0.7828, Ratio: 0.7111
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 14.9, Modularity F 3D: 0.4203, Modularity 3D: 0.7828, Ratio: 0.5369
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 15.2, Modularity F 3D: 0.6087, Modularity 3D: 0.7828, Ratio: 0.7776
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 15.6, Modularity F 3D: 0.5798, Modularity 3D: 0.7828, Ratio: 0.7406
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 16.0, Modularity F 3D: 0.5664, Modularity 3D: 0.7828, Ratio: 0.7235
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 16.3, Modularity F 3D: 0.5680, Modularity 3D: 0.7828, Ratio: 0.7256
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 16.7, Modularity F 3D: 0.6256, Modularity 3D: 0.7828, Ratio: 0.7992
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 17.1, Modularity F 3D: 0.5126, Modularity 3D: 0.7828, Ratio: 0.6549
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 17.4, Modularity F 3D: 0.5761, Modularity 3D: 0.7828, Ratio: 0.7360
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 17.8, Modularity F 3D: 0.6210, Modularity 3D: 0.7828, Ratio: 0.7933
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 18.2, Modularity F 3D: 0.4558, Modularity 3D: 0.7828, Ratio: 0.5823
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 18.5, Modularity F 3D: 0.5022, Modularity 3D: 0.7828, Ratio: 0.6415
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 18.9, Modularity F 3D: 0.5062, Modularity 3D: 0.7828, Ratio: 0.6466
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 19.3, Modularity F 3D: 0.5762, Modularity 3D: 0.7828, Ratio: 0.7361
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 19.6, Modularity F 3D: 0.4839, Modularity 3D: 0.7828, Ratio: 0.6182
# Sigma: 0.0367, Gini: 0.8353, Exc Weight: 20.0, Modularity F 3D: 0.5004, Modularity 3D: 0.7828, Ratio: 0.6393
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 2.0, Modularity F 3D: 0.1205, Modularity 3D: 0.7574, Ratio: 0.1591
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 2.4, Modularity F 3D: 0.1210, Modularity 3D: 0.7574, Ratio: 0.1597
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 2.7, Modularity F 3D: 0.1168, Modularity 3D: 0.7574, Ratio: 0.1542
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 3.1, Modularity F 3D: 0.1092, Modularity 3D: 0.7574, Ratio: 0.1442
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 3.5, Modularity F 3D: 0.1161, Modularity 3D: 0.7574, Ratio: 0.1532
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 3.8, Modularity F 3D: 0.0973, Modularity 3D: 0.7574, Ratio: 0.1285
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 4.2, Modularity F 3D: 0.1085, Modularity 3D: 0.7574, Ratio: 0.1432
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 4.6, Modularity F 3D: 0.1053, Modularity 3D: 0.7574, Ratio: 0.1390
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 4.9, Modularity F 3D: 0.1112, Modularity 3D: 0.7574, Ratio: 0.1469
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 5.3, Modularity F 3D: 0.0764, Modularity 3D: 0.7574, Ratio: 0.1009
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 5.7, Modularity F 3D: 0.0860, Modularity 3D: 0.7574, Ratio: 0.1135
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 6.0, Modularity F 3D: 0.0712, Modularity 3D: 0.7574, Ratio: 0.0940
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 6.4, Modularity F 3D: 0.0703, Modularity 3D: 0.7574, Ratio: 0.0928
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 6.8, Modularity F 3D: 0.0778, Modularity 3D: 0.7574, Ratio: 0.1027
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 7.1, Modularity F 3D: 0.0846, Modularity 3D: 0.7574, Ratio: 0.1116
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 7.5, Modularity F 3D: 0.1233, Modularity 3D: 0.7574, Ratio: 0.1628
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 7.9, Modularity F 3D: 0.4022, Modularity 3D: 0.7574, Ratio: 0.5311
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 8.2, Modularity F 3D: 0.4742, Modularity 3D: 0.7574, Ratio: 0.6261
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 8.6, Modularity F 3D: 0.4748, Modularity 3D: 0.7574, Ratio: 0.6270
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 9.0, Modularity F 3D: 0.4294, Modularity 3D: 0.7574, Ratio: 0.5670
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 9.3, Modularity F 3D: 0.5446, Modularity 3D: 0.7574, Ratio: 0.7190
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 9.7, Modularity F 3D: 0.5191, Modularity 3D: 0.7574, Ratio: 0.6854
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 10.1, Modularity F 3D: 0.5355, Modularity 3D: 0.7574, Ratio: 0.7071
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 10.4, Modularity F 3D: 0.4744, Modularity 3D: 0.7574, Ratio: 0.6264
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 10.8, Modularity F 3D: 0.5584, Modularity 3D: 0.7574, Ratio: 0.7373
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 11.2, Modularity F 3D: 0.4667, Modularity 3D: 0.7574, Ratio: 0.6163
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 11.6, Modularity F 3D: 0.4938, Modularity 3D: 0.7574, Ratio: 0.6521
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 11.9, Modularity F 3D: 0.4888, Modularity 3D: 0.7574, Ratio: 0.6455
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 12.3, Modularity F 3D: 0.4662, Modularity 3D: 0.7574, Ratio: 0.6155
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 12.7, Modularity F 3D: 0.4670, Modularity 3D: 0.7574, Ratio: 0.6167
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 13.0, Modularity F 3D: 0.5134, Modularity 3D: 0.7574, Ratio: 0.6779
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 13.4, Modularity F 3D: 0.4207, Modularity 3D: 0.7574, Ratio: 0.5555
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 13.8, Modularity F 3D: 0.3880, Modularity 3D: 0.7574, Ratio: 0.5123
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 14.1, Modularity F 3D: 0.4908, Modularity 3D: 0.7574, Ratio: 0.6480
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 14.5, Modularity F 3D: 0.4874, Modularity 3D: 0.7574, Ratio: 0.6435
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 14.9, Modularity F 3D: 0.4156, Modularity 3D: 0.7574, Ratio: 0.5488
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 15.2, Modularity F 3D: 0.5650, Modularity 3D: 0.7574, Ratio: 0.7460
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 15.6, Modularity F 3D: 0.4958, Modularity 3D: 0.7574, Ratio: 0.6546
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 16.0, Modularity F 3D: 0.4570, Modularity 3D: 0.7574, Ratio: 0.6034
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 16.3, Modularity F 3D: 0.3468, Modularity 3D: 0.7574, Ratio: 0.4579
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 16.7, Modularity F 3D: 0.4659, Modularity 3D: 0.7574, Ratio: 0.6152
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 17.1, Modularity F 3D: 0.5389, Modularity 3D: 0.7574, Ratio: 0.7116
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 17.4, Modularity F 3D: 0.4853, Modularity 3D: 0.7574, Ratio: 0.6408
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 17.8, Modularity F 3D: 0.5512, Modularity 3D: 0.7574, Ratio: 0.7278
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 18.2, Modularity F 3D: 0.4927, Modularity 3D: 0.7574, Ratio: 0.6506
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 18.5, Modularity F 3D: 0.5437, Modularity 3D: 0.7574, Ratio: 0.7179
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 18.9, Modularity F 3D: 0.4644, Modularity 3D: 0.7574, Ratio: 0.6132
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 19.3, Modularity F 3D: 0.5043, Modularity 3D: 0.7574, Ratio: 0.6659
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 19.6, Modularity F 3D: 0.6333, Modularity 3D: 0.7574, Ratio: 0.8363
# Sigma: 0.0397, Gini: 0.8256, Exc Weight: 20.0, Modularity F 3D: 0.5605, Modularity 3D: 0.7574, Ratio: 0.7401
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 2.0, Modularity F 3D: 0.1188, Modularity 3D: 0.7715, Ratio: 0.1540
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 2.4, Modularity F 3D: 0.1172, Modularity 3D: 0.7715, Ratio: 0.1520
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 2.7, Modularity F 3D: 0.1117, Modularity 3D: 0.7715, Ratio: 0.1448
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 3.1, Modularity F 3D: 0.1209, Modularity 3D: 0.7715, Ratio: 0.1568
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 3.5, Modularity F 3D: 0.1164, Modularity 3D: 0.7715, Ratio: 0.1508
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 3.8, Modularity F 3D: 0.1151, Modularity 3D: 0.7715, Ratio: 0.1492
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 4.2, Modularity F 3D: 0.0940, Modularity 3D: 0.7715, Ratio: 0.1218
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 4.6, Modularity F 3D: 0.1044, Modularity 3D: 0.7715, Ratio: 0.1353
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 4.9, Modularity F 3D: 0.1039, Modularity 3D: 0.7715, Ratio: 0.1346
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 5.3, Modularity F 3D: 0.0937, Modularity 3D: 0.7715, Ratio: 0.1215
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 5.7, Modularity F 3D: 0.0739, Modularity 3D: 0.7715, Ratio: 0.0958
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 6.0, Modularity F 3D: 0.1742, Modularity 3D: 0.7715, Ratio: 0.2257
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 6.4, Modularity F 3D: 0.0742, Modularity 3D: 0.7715, Ratio: 0.0962
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 6.8, Modularity F 3D: 0.2874, Modularity 3D: 0.7715, Ratio: 0.3725
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 7.1, Modularity F 3D: 0.2623, Modularity 3D: 0.7715, Ratio: 0.3400
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 7.5, Modularity F 3D: 0.2477, Modularity 3D: 0.7715, Ratio: 0.3210
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 7.9, Modularity F 3D: 0.3461, Modularity 3D: 0.7715, Ratio: 0.4486
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 8.2, Modularity F 3D: 0.4311, Modularity 3D: 0.7715, Ratio: 0.5587
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 8.6, Modularity F 3D: 0.4351, Modularity 3D: 0.7715, Ratio: 0.5640
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 9.0, Modularity F 3D: 0.5109, Modularity 3D: 0.7715, Ratio: 0.6621
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 9.3, Modularity F 3D: 0.5237, Modularity 3D: 0.7715, Ratio: 0.6788
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 9.7, Modularity F 3D: 0.4898, Modularity 3D: 0.7715, Ratio: 0.6348
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 10.1, Modularity F 3D: 0.5193, Modularity 3D: 0.7715, Ratio: 0.6731
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 10.4, Modularity F 3D: 0.5107, Modularity 3D: 0.7715, Ratio: 0.6620
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 10.8, Modularity F 3D: 0.5101, Modularity 3D: 0.7715, Ratio: 0.6611
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 11.2, Modularity F 3D: 0.4375, Modularity 3D: 0.7715, Ratio: 0.5670
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 11.6, Modularity F 3D: 0.5579, Modularity 3D: 0.7715, Ratio: 0.7231
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 11.9, Modularity F 3D: 0.4983, Modularity 3D: 0.7715, Ratio: 0.6459
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 12.3, Modularity F 3D: 0.5187, Modularity 3D: 0.7715, Ratio: 0.6723
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 12.7, Modularity F 3D: 0.5060, Modularity 3D: 0.7715, Ratio: 0.6559
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 13.0, Modularity F 3D: 0.5129, Modularity 3D: 0.7715, Ratio: 0.6648
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 13.4, Modularity F 3D: 0.5616, Modularity 3D: 0.7715, Ratio: 0.7278
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 13.8, Modularity F 3D: 0.4323, Modularity 3D: 0.7715, Ratio: 0.5603
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 14.1, Modularity F 3D: 0.4689, Modularity 3D: 0.7715, Ratio: 0.6078
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 14.5, Modularity F 3D: 0.4371, Modularity 3D: 0.7715, Ratio: 0.5665
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 14.9, Modularity F 3D: 0.5359, Modularity 3D: 0.7715, Ratio: 0.6946
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 15.2, Modularity F 3D: 0.4920, Modularity 3D: 0.7715, Ratio: 0.6377
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 15.6, Modularity F 3D: 0.4728, Modularity 3D: 0.7715, Ratio: 0.6128
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 16.0, Modularity F 3D: 0.4214, Modularity 3D: 0.7715, Ratio: 0.5462
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 16.3, Modularity F 3D: 0.4568, Modularity 3D: 0.7715, Ratio: 0.5920
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 16.7, Modularity F 3D: 0.4116, Modularity 3D: 0.7715, Ratio: 0.5335
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 17.1, Modularity F 3D: 0.4887, Modularity 3D: 0.7715, Ratio: 0.6334
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 17.4, Modularity F 3D: 0.4334, Modularity 3D: 0.7715, Ratio: 0.5617
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 17.8, Modularity F 3D: 0.5928, Modularity 3D: 0.7715, Ratio: 0.7683
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 18.2, Modularity F 3D: 0.5153, Modularity 3D: 0.7715, Ratio: 0.6679
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 18.5, Modularity F 3D: 0.4050, Modularity 3D: 0.7715, Ratio: 0.5249
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 18.9, Modularity F 3D: 0.5313, Modularity 3D: 0.7715, Ratio: 0.6886
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 19.3, Modularity F 3D: 0.5208, Modularity 3D: 0.7715, Ratio: 0.6750
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 19.6, Modularity F 3D: 0.5583, Modularity 3D: 0.7715, Ratio: 0.7236
# Sigma: 0.0425, Gini: 0.8159, Exc Weight: 20.0, Modularity F 3D: 0.5666, Modularity 3D: 0.7715, Ratio: 0.7344
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 2.0, Modularity F 3D: 0.1233, Modularity 3D: 0.7614, Ratio: 0.1619
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 2.4, Modularity F 3D: 0.1204, Modularity 3D: 0.7614, Ratio: 0.1582
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 2.7, Modularity F 3D: 0.1218, Modularity 3D: 0.7614, Ratio: 0.1600
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 3.1, Modularity F 3D: 0.1174, Modularity 3D: 0.7614, Ratio: 0.1542
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 3.5, Modularity F 3D: 0.1184, Modularity 3D: 0.7614, Ratio: 0.1554
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 3.8, Modularity F 3D: 0.1056, Modularity 3D: 0.7614, Ratio: 0.1386
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 4.2, Modularity F 3D: 0.1080, Modularity 3D: 0.7614, Ratio: 0.1418
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 4.6, Modularity F 3D: 0.1121, Modularity 3D: 0.7614, Ratio: 0.1472
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 4.9, Modularity F 3D: 0.1076, Modularity 3D: 0.7614, Ratio: 0.1413
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 5.3, Modularity F 3D: 0.1032, Modularity 3D: 0.7614, Ratio: 0.1356
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 5.7, Modularity F 3D: 0.0922, Modularity 3D: 0.7614, Ratio: 0.1212
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 6.0, Modularity F 3D: 0.0722, Modularity 3D: 0.7614, Ratio: 0.0948
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 6.4, Modularity F 3D: 0.0750, Modularity 3D: 0.7614, Ratio: 0.0985
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 6.8, Modularity F 3D: 0.3273, Modularity 3D: 0.7614, Ratio: 0.4299
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 7.1, Modularity F 3D: 0.3487, Modularity 3D: 0.7614, Ratio: 0.4580
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 7.5, Modularity F 3D: 0.3982, Modularity 3D: 0.7614, Ratio: 0.5230
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 7.9, Modularity F 3D: 0.5453, Modularity 3D: 0.7614, Ratio: 0.7162
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 8.2, Modularity F 3D: 0.5316, Modularity 3D: 0.7614, Ratio: 0.6982
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 8.6, Modularity F 3D: 0.5844, Modularity 3D: 0.7614, Ratio: 0.7676
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 9.0, Modularity F 3D: 0.5346, Modularity 3D: 0.7614, Ratio: 0.7021
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 9.3, Modularity F 3D: 0.5627, Modularity 3D: 0.7614, Ratio: 0.7390
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 9.7, Modularity F 3D: 0.5779, Modularity 3D: 0.7614, Ratio: 0.7590
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 10.1, Modularity F 3D: 0.5354, Modularity 3D: 0.7614, Ratio: 0.7032
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 10.4, Modularity F 3D: 0.5354, Modularity 3D: 0.7614, Ratio: 0.7032
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 10.8, Modularity F 3D: 0.5236, Modularity 3D: 0.7614, Ratio: 0.6877
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 11.2, Modularity F 3D: 0.5855, Modularity 3D: 0.7614, Ratio: 0.7690
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 11.6, Modularity F 3D: 0.5921, Modularity 3D: 0.7614, Ratio: 0.7777
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 11.9, Modularity F 3D: 0.5286, Modularity 3D: 0.7614, Ratio: 0.6943
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 12.3, Modularity F 3D: 0.5096, Modularity 3D: 0.7614, Ratio: 0.6693
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 12.7, Modularity F 3D: 0.5403, Modularity 3D: 0.7614, Ratio: 0.7096
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 13.0, Modularity F 3D: 0.4922, Modularity 3D: 0.7614, Ratio: 0.6464
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 13.4, Modularity F 3D: 0.5094, Modularity 3D: 0.7614, Ratio: 0.6690
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 13.8, Modularity F 3D: 0.5480, Modularity 3D: 0.7614, Ratio: 0.7197
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 14.1, Modularity F 3D: 0.5572, Modularity 3D: 0.7614, Ratio: 0.7317
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 14.5, Modularity F 3D: 0.5331, Modularity 3D: 0.7614, Ratio: 0.7002
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 14.9, Modularity F 3D: 0.5103, Modularity 3D: 0.7614, Ratio: 0.6702
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 15.2, Modularity F 3D: 0.5217, Modularity 3D: 0.7614, Ratio: 0.6852
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 15.6, Modularity F 3D: 0.4782, Modularity 3D: 0.7614, Ratio: 0.6281
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 16.0, Modularity F 3D: 0.5460, Modularity 3D: 0.7614, Ratio: 0.7172
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 16.3, Modularity F 3D: 0.4406, Modularity 3D: 0.7614, Ratio: 0.5787
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 16.7, Modularity F 3D: 0.5817, Modularity 3D: 0.7614, Ratio: 0.7639
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 17.1, Modularity F 3D: 0.5099, Modularity 3D: 0.7614, Ratio: 0.6697
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 17.4, Modularity F 3D: 0.3922, Modularity 3D: 0.7614, Ratio: 0.5151
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 17.8, Modularity F 3D: 0.5581, Modularity 3D: 0.7614, Ratio: 0.7330
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 18.2, Modularity F 3D: 0.5932, Modularity 3D: 0.7614, Ratio: 0.7790
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 18.5, Modularity F 3D: 0.5545, Modularity 3D: 0.7614, Ratio: 0.7283
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 18.9, Modularity F 3D: 0.5215, Modularity 3D: 0.7614, Ratio: 0.6849
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 19.3, Modularity F 3D: 0.5795, Modularity 3D: 0.7614, Ratio: 0.7611
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 19.6, Modularity F 3D: 0.5780, Modularity 3D: 0.7614, Ratio: 0.7591
# Sigma: 0.0449, Gini: 0.8062, Exc Weight: 20.0, Modularity F 3D: 0.6040, Modularity 3D: 0.7614, Ratio: 0.7933
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 2.0, Modularity F 3D: 0.1194, Modularity 3D: 0.7504, Ratio: 0.1592
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 2.4, Modularity F 3D: 0.1183, Modularity 3D: 0.7504, Ratio: 0.1577
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 2.7, Modularity F 3D: 0.1227, Modularity 3D: 0.7504, Ratio: 0.1635
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 3.1, Modularity F 3D: 0.1156, Modularity 3D: 0.7504, Ratio: 0.1540
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 3.5, Modularity F 3D: 0.1170, Modularity 3D: 0.7504, Ratio: 0.1559
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 3.8, Modularity F 3D: 0.1135, Modularity 3D: 0.7504, Ratio: 0.1512
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 4.2, Modularity F 3D: 0.1144, Modularity 3D: 0.7504, Ratio: 0.1524
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 4.6, Modularity F 3D: 0.0877, Modularity 3D: 0.7504, Ratio: 0.1169
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 4.9, Modularity F 3D: 0.0720, Modularity 3D: 0.7504, Ratio: 0.0959
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 5.3, Modularity F 3D: 0.0907, Modularity 3D: 0.7504, Ratio: 0.1208
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 5.7, Modularity F 3D: 0.1046, Modularity 3D: 0.7504, Ratio: 0.1393
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 6.0, Modularity F 3D: 0.0875, Modularity 3D: 0.7504, Ratio: 0.1166
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 6.4, Modularity F 3D: 0.0722, Modularity 3D: 0.7504, Ratio: 0.0962
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 6.8, Modularity F 3D: 0.0784, Modularity 3D: 0.7504, Ratio: 0.1045
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 7.1, Modularity F 3D: 0.1206, Modularity 3D: 0.7504, Ratio: 0.1607
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 7.5, Modularity F 3D: 0.5131, Modularity 3D: 0.7504, Ratio: 0.6837
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 7.9, Modularity F 3D: 0.5684, Modularity 3D: 0.7504, Ratio: 0.7574
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 8.2, Modularity F 3D: 0.6364, Modularity 3D: 0.7504, Ratio: 0.8480
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 8.6, Modularity F 3D: 0.6228, Modularity 3D: 0.7504, Ratio: 0.8299
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 9.0, Modularity F 3D: 0.6177, Modularity 3D: 0.7504, Ratio: 0.8231
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 9.3, Modularity F 3D: 0.6278, Modularity 3D: 0.7504, Ratio: 0.8366
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 9.7, Modularity F 3D: 0.6020, Modularity 3D: 0.7504, Ratio: 0.8022
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 10.1, Modularity F 3D: 0.5989, Modularity 3D: 0.7504, Ratio: 0.7981
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 10.4, Modularity F 3D: 0.6025, Modularity 3D: 0.7504, Ratio: 0.8029
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 10.8, Modularity F 3D: 0.5641, Modularity 3D: 0.7504, Ratio: 0.7518
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 11.2, Modularity F 3D: 0.5746, Modularity 3D: 0.7504, Ratio: 0.7658
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 11.6, Modularity F 3D: 0.5456, Modularity 3D: 0.7504, Ratio: 0.7271
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 11.9, Modularity F 3D: 0.5520, Modularity 3D: 0.7504, Ratio: 0.7355
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 12.3, Modularity F 3D: 0.5973, Modularity 3D: 0.7504, Ratio: 0.7959
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 12.7, Modularity F 3D: 0.5506, Modularity 3D: 0.7504, Ratio: 0.7337
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 13.0, Modularity F 3D: 0.5618, Modularity 3D: 0.7504, Ratio: 0.7487
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 13.4, Modularity F 3D: 0.5281, Modularity 3D: 0.7504, Ratio: 0.7037
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 13.8, Modularity F 3D: 0.5512, Modularity 3D: 0.7504, Ratio: 0.7345
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 14.1, Modularity F 3D: 0.5045, Modularity 3D: 0.7504, Ratio: 0.6722
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 14.5, Modularity F 3D: 0.4794, Modularity 3D: 0.7504, Ratio: 0.6388
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 14.9, Modularity F 3D: 0.5496, Modularity 3D: 0.7504, Ratio: 0.7324
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 15.2, Modularity F 3D: 0.5141, Modularity 3D: 0.7504, Ratio: 0.6851
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 15.6, Modularity F 3D: 0.4568, Modularity 3D: 0.7504, Ratio: 0.6087
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 16.0, Modularity F 3D: 0.5431, Modularity 3D: 0.7504, Ratio: 0.7237
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 16.3, Modularity F 3D: 0.4946, Modularity 3D: 0.7504, Ratio: 0.6591
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 16.7, Modularity F 3D: 0.5023, Modularity 3D: 0.7504, Ratio: 0.6694
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 17.1, Modularity F 3D: 0.5149, Modularity 3D: 0.7504, Ratio: 0.6861
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 17.4, Modularity F 3D: 0.4937, Modularity 3D: 0.7504, Ratio: 0.6579
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 17.8, Modularity F 3D: 0.4032, Modularity 3D: 0.7504, Ratio: 0.5373
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 18.2, Modularity F 3D: 0.4918, Modularity 3D: 0.7504, Ratio: 0.6554
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 18.5, Modularity F 3D: 0.4856, Modularity 3D: 0.7504, Ratio: 0.6470
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 18.9, Modularity F 3D: 0.3690, Modularity 3D: 0.7504, Ratio: 0.4918
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 19.3, Modularity F 3D: 0.5907, Modularity 3D: 0.7504, Ratio: 0.7871
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 19.6, Modularity F 3D: 0.5235, Modularity 3D: 0.7504, Ratio: 0.6977
# Sigma: 0.0473, Gini: 0.7965, Exc Weight: 20.0, Modularity F 3D: 0.3145, Modularity 3D: 0.7504, Ratio: 0.4191
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 2.0, Modularity F 3D: 0.1135, Modularity 3D: 0.7370, Ratio: 0.1540
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 2.4, Modularity F 3D: 0.1161, Modularity 3D: 0.7370, Ratio: 0.1575
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 2.7, Modularity F 3D: 0.1192, Modularity 3D: 0.7370, Ratio: 0.1617
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 3.1, Modularity F 3D: 0.1110, Modularity 3D: 0.7370, Ratio: 0.1506
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 3.5, Modularity F 3D: 0.1203, Modularity 3D: 0.7370, Ratio: 0.1633
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 3.8, Modularity F 3D: 0.1160, Modularity 3D: 0.7370, Ratio: 0.1574
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 4.2, Modularity F 3D: 0.1102, Modularity 3D: 0.7370, Ratio: 0.1496
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 4.6, Modularity F 3D: 0.1154, Modularity 3D: 0.7370, Ratio: 0.1565
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 4.9, Modularity F 3D: 0.1107, Modularity 3D: 0.7370, Ratio: 0.1503
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 5.3, Modularity F 3D: 0.0815, Modularity 3D: 0.7370, Ratio: 0.1105
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 5.7, Modularity F 3D: 0.0915, Modularity 3D: 0.7370, Ratio: 0.1242
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 6.0, Modularity F 3D: 0.0919, Modularity 3D: 0.7370, Ratio: 0.1248
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 6.4, Modularity F 3D: 0.0730, Modularity 3D: 0.7370, Ratio: 0.0990
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 6.8, Modularity F 3D: 0.0749, Modularity 3D: 0.7370, Ratio: 0.1016
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 7.1, Modularity F 3D: 0.0785, Modularity 3D: 0.7370, Ratio: 0.1065
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 7.5, Modularity F 3D: 0.1333, Modularity 3D: 0.7370, Ratio: 0.1809
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 7.9, Modularity F 3D: 0.3145, Modularity 3D: 0.7370, Ratio: 0.4268
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 8.2, Modularity F 3D: 0.2488, Modularity 3D: 0.7370, Ratio: 0.3376
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 8.6, Modularity F 3D: 0.2892, Modularity 3D: 0.7370, Ratio: 0.3924
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 9.0, Modularity F 3D: 0.4197, Modularity 3D: 0.7370, Ratio: 0.5695
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 9.3, Modularity F 3D: 0.3441, Modularity 3D: 0.7370, Ratio: 0.4669
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 9.7, Modularity F 3D: 0.3746, Modularity 3D: 0.7370, Ratio: 0.5083
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 10.1, Modularity F 3D: 0.4394, Modularity 3D: 0.7370, Ratio: 0.5962
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 10.4, Modularity F 3D: 0.4165, Modularity 3D: 0.7370, Ratio: 0.5651
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 10.8, Modularity F 3D: 0.3961, Modularity 3D: 0.7370, Ratio: 0.5374
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 11.2, Modularity F 3D: 0.3668, Modularity 3D: 0.7370, Ratio: 0.4977
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 11.6, Modularity F 3D: 0.3522, Modularity 3D: 0.7370, Ratio: 0.4780
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 11.9, Modularity F 3D: 0.4276, Modularity 3D: 0.7370, Ratio: 0.5802
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 12.3, Modularity F 3D: 0.3936, Modularity 3D: 0.7370, Ratio: 0.5340
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 12.7, Modularity F 3D: 0.4290, Modularity 3D: 0.7370, Ratio: 0.5821
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 13.0, Modularity F 3D: 0.4557, Modularity 3D: 0.7370, Ratio: 0.6183
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 13.4, Modularity F 3D: 0.3934, Modularity 3D: 0.7370, Ratio: 0.5339
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 13.8, Modularity F 3D: 0.2766, Modularity 3D: 0.7370, Ratio: 0.3753
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 14.1, Modularity F 3D: 0.4433, Modularity 3D: 0.7370, Ratio: 0.6015
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 14.5, Modularity F 3D: 0.4159, Modularity 3D: 0.7370, Ratio: 0.5644
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 14.9, Modularity F 3D: 0.4580, Modularity 3D: 0.7370, Ratio: 0.6215
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 15.2, Modularity F 3D: 0.3960, Modularity 3D: 0.7370, Ratio: 0.5373
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 15.6, Modularity F 3D: 0.4445, Modularity 3D: 0.7370, Ratio: 0.6031
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 16.0, Modularity F 3D: 0.5018, Modularity 3D: 0.7370, Ratio: 0.6809
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 16.3, Modularity F 3D: 0.4106, Modularity 3D: 0.7370, Ratio: 0.5572
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 16.7, Modularity F 3D: 0.4607, Modularity 3D: 0.7370, Ratio: 0.6251
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 17.1, Modularity F 3D: 0.3925, Modularity 3D: 0.7370, Ratio: 0.5326
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 17.4, Modularity F 3D: 0.4312, Modularity 3D: 0.7370, Ratio: 0.5851
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 17.8, Modularity F 3D: 0.4536, Modularity 3D: 0.7370, Ratio: 0.6154
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 18.2, Modularity F 3D: 0.4393, Modularity 3D: 0.7370, Ratio: 0.5961
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 18.5, Modularity F 3D: 0.5235, Modularity 3D: 0.7370, Ratio: 0.7103
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 18.9, Modularity F 3D: 0.4543, Modularity 3D: 0.7370, Ratio: 0.6164
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 19.3, Modularity F 3D: 0.5498, Modularity 3D: 0.7370, Ratio: 0.7461
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 19.6, Modularity F 3D: 0.3392, Modularity 3D: 0.7370, Ratio: 0.4603
# Sigma: 0.0494, Gini: 0.7868, Exc Weight: 20.0, Modularity F 3D: 0.4910, Modularity 3D: 0.7370, Ratio: 0.6662
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 2.0, Modularity F 3D: 0.1184, Modularity 3D: 0.7366, Ratio: 0.1607
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 2.4, Modularity F 3D: 0.1238, Modularity 3D: 0.7366, Ratio: 0.1680
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 2.7, Modularity F 3D: 0.1180, Modularity 3D: 0.7366, Ratio: 0.1602
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 3.1, Modularity F 3D: 0.1184, Modularity 3D: 0.7366, Ratio: 0.1607
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 3.5, Modularity F 3D: 0.1208, Modularity 3D: 0.7366, Ratio: 0.1640
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 3.8, Modularity F 3D: 0.1163, Modularity 3D: 0.7366, Ratio: 0.1579
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 4.2, Modularity F 3D: 0.1015, Modularity 3D: 0.7366, Ratio: 0.1377
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 4.6, Modularity F 3D: 0.1129, Modularity 3D: 0.7366, Ratio: 0.1532
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 4.9, Modularity F 3D: 0.0863, Modularity 3D: 0.7366, Ratio: 0.1171
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 5.3, Modularity F 3D: 0.1084, Modularity 3D: 0.7366, Ratio: 0.1472
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 5.7, Modularity F 3D: 0.0684, Modularity 3D: 0.7366, Ratio: 0.0929
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 6.0, Modularity F 3D: 0.0821, Modularity 3D: 0.7366, Ratio: 0.1114
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 6.4, Modularity F 3D: 0.0728, Modularity 3D: 0.7366, Ratio: 0.0988
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 6.8, Modularity F 3D: 0.0696, Modularity 3D: 0.7366, Ratio: 0.0946
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 7.1, Modularity F 3D: 0.2930, Modularity 3D: 0.7366, Ratio: 0.3978
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 7.5, Modularity F 3D: 0.4889, Modularity 3D: 0.7366, Ratio: 0.6637
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 7.9, Modularity F 3D: 0.4940, Modularity 3D: 0.7366, Ratio: 0.6707
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 8.2, Modularity F 3D: 0.4529, Modularity 3D: 0.7366, Ratio: 0.6148
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 8.6, Modularity F 3D: 0.4115, Modularity 3D: 0.7366, Ratio: 0.5586
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 9.0, Modularity F 3D: 0.4300, Modularity 3D: 0.7366, Ratio: 0.5837
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 9.3, Modularity F 3D: 0.4701, Modularity 3D: 0.7366, Ratio: 0.6382
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 9.7, Modularity F 3D: 0.4380, Modularity 3D: 0.7366, Ratio: 0.5946
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 10.1, Modularity F 3D: 0.4635, Modularity 3D: 0.7366, Ratio: 0.6293
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 10.4, Modularity F 3D: 0.4722, Modularity 3D: 0.7366, Ratio: 0.6410
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 10.8, Modularity F 3D: 0.4441, Modularity 3D: 0.7366, Ratio: 0.6029
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 11.2, Modularity F 3D: 0.4680, Modularity 3D: 0.7366, Ratio: 0.6353
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 11.6, Modularity F 3D: 0.4632, Modularity 3D: 0.7366, Ratio: 0.6289
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 11.9, Modularity F 3D: 0.4268, Modularity 3D: 0.7366, Ratio: 0.5795
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 12.3, Modularity F 3D: 0.4867, Modularity 3D: 0.7366, Ratio: 0.6607
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 12.7, Modularity F 3D: 0.4549, Modularity 3D: 0.7366, Ratio: 0.6175
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 13.0, Modularity F 3D: 0.4702, Modularity 3D: 0.7366, Ratio: 0.6384
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 13.4, Modularity F 3D: 0.4944, Modularity 3D: 0.7366, Ratio: 0.6713
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 13.8, Modularity F 3D: 0.4335, Modularity 3D: 0.7366, Ratio: 0.5885
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 14.1, Modularity F 3D: 0.4196, Modularity 3D: 0.7366, Ratio: 0.5696
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 14.5, Modularity F 3D: 0.4851, Modularity 3D: 0.7366, Ratio: 0.6585
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 14.9, Modularity F 3D: 0.3886, Modularity 3D: 0.7366, Ratio: 0.5276
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 15.2, Modularity F 3D: 0.4406, Modularity 3D: 0.7366, Ratio: 0.5981
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 15.6, Modularity F 3D: 0.4154, Modularity 3D: 0.7366, Ratio: 0.5640
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 16.0, Modularity F 3D: 0.4341, Modularity 3D: 0.7366, Ratio: 0.5893
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 16.3, Modularity F 3D: 0.4985, Modularity 3D: 0.7366, Ratio: 0.6767
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 16.7, Modularity F 3D: 0.5271, Modularity 3D: 0.7366, Ratio: 0.7156
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 17.1, Modularity F 3D: 0.5340, Modularity 3D: 0.7366, Ratio: 0.7249
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 17.4, Modularity F 3D: 0.4835, Modularity 3D: 0.7366, Ratio: 0.6564
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 17.8, Modularity F 3D: 0.5390, Modularity 3D: 0.7366, Ratio: 0.7318
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 18.2, Modularity F 3D: 0.5324, Modularity 3D: 0.7366, Ratio: 0.7228
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 18.5, Modularity F 3D: 0.5097, Modularity 3D: 0.7366, Ratio: 0.6920
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 18.9, Modularity F 3D: 0.5153, Modularity 3D: 0.7366, Ratio: 0.6996
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 19.3, Modularity F 3D: 0.4924, Modularity 3D: 0.7366, Ratio: 0.6685
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 19.6, Modularity F 3D: 0.5397, Modularity 3D: 0.7366, Ratio: 0.7326
# Sigma: 0.0515, Gini: 0.7771, Exc Weight: 20.0, Modularity F 3D: 0.4584, Modularity 3D: 0.7366, Ratio: 0.6223
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 2.0, Modularity F 3D: 0.1177, Modularity 3D: 0.7559, Ratio: 0.1558
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 2.4, Modularity F 3D: 0.1224, Modularity 3D: 0.7559, Ratio: 0.1620
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 2.7, Modularity F 3D: 0.1196, Modularity 3D: 0.7559, Ratio: 0.1583
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 3.1, Modularity F 3D: 0.1107, Modularity 3D: 0.7559, Ratio: 0.1464
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 3.5, Modularity F 3D: 0.1198, Modularity 3D: 0.7559, Ratio: 0.1585
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 3.8, Modularity F 3D: 0.1097, Modularity 3D: 0.7559, Ratio: 0.1451
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 4.2, Modularity F 3D: 0.1092, Modularity 3D: 0.7559, Ratio: 0.1444
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 4.6, Modularity F 3D: 0.1094, Modularity 3D: 0.7559, Ratio: 0.1447
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 4.9, Modularity F 3D: 0.1008, Modularity 3D: 0.7559, Ratio: 0.1333
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 5.3, Modularity F 3D: 0.1016, Modularity 3D: 0.7559, Ratio: 0.1345
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 5.7, Modularity F 3D: 0.0751, Modularity 3D: 0.7559, Ratio: 0.0993
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 6.0, Modularity F 3D: 0.0750, Modularity 3D: 0.7559, Ratio: 0.0992
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 6.4, Modularity F 3D: 0.0822, Modularity 3D: 0.7559, Ratio: 0.1087
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 6.8, Modularity F 3D: 0.0725, Modularity 3D: 0.7559, Ratio: 0.0959
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 7.1, Modularity F 3D: 0.2464, Modularity 3D: 0.7559, Ratio: 0.3260
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 7.5, Modularity F 3D: 0.3163, Modularity 3D: 0.7559, Ratio: 0.4185
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 7.9, Modularity F 3D: 0.3355, Modularity 3D: 0.7559, Ratio: 0.4438
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 8.2, Modularity F 3D: 0.2937, Modularity 3D: 0.7559, Ratio: 0.3885
# Sigma: 0.0536, Gini: 0.7674, Exc Weight: 8.6, Modularity F 3D: 0.4949, Modularity 3D: 0.7559, Ratio: 0.6548
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc8.980_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=9.0
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc9.347_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=9.3
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc9.714_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=9.7
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc10.082_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=10.1
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc10.449_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=10.4
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc10.816_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=10.8
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc11.184_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=11.2
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc11.551_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=11.6
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc11.918_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=11.9
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc12.286_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=12.3
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc12.653_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=12.7
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc13.020_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=13.0
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc13.388_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=13.4
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc13.755_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=13.8
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc14.122_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=14.1
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc14.490_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=14.5
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc14.857_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=14.9
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc15.224_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=15.2
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc15.592_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=15.6
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc15.959_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=16.0
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc16.327_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=16.3
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc16.694_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=16.7
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc17.061_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=17.1
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc17.429_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=17.4
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc17.796_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=17.8
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc18.163_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=18.2
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc18.531_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=18.5
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc18.898_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=18.9
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc19.265_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=19.3
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc19.633_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=19.6
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0536_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc20.000_sim0.txt
# Archivo no encontrado para sigma=0.0536, exc_weight=20.0
# Archivo no encontrado: 3D_dynamics/networks_for_dynamics/3D_adjacency_matrix_cube_SW_agg_nc112_s0.0557_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_sim0.txt
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0557_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc8.612_sim0.txt
# Archivo no encontrado para sigma=0.0557
# Archivo no encontrado: 3D_dynamics/networks_for_dynamics/3D_adjacency_matrix_cube_SW_agg_nc112_s0.0578_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_sim0.txt
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0578_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc8.612_sim0.txt
# Archivo no encontrado para sigma=0.0578
# Archivo no encontrado: 3D_dynamics/networks_for_dynamics/3D_adjacency_matrix_cube_SW_agg_nc112_s0.0600_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_sim0.txt
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0600_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc8.612_sim0.txt
# Archivo no encontrado para sigma=0.0600
# Archivo no encontrado: 3D_dynamics/networks_for_dynamics/3D_adjacency_matrix_cube_SW_agg_nc112_s0.0621_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_sim0.txt
# Archivo no encontrado: 3D_dynamics/3D_dynamics_cube_SW_agg_nc112_s0.0621_L2.0_h1.00_rho1400_l0.70_d0.15_a0.20_exc8.612_sim0.txt
# Archivo no encontrado para sigma=0.0621
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 2.0, Modularity F 3D: 0.1215, Modularity 3D: 0.7248, Ratio: 0.1677
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 2.4, Modularity F 3D: 0.1194, Modularity 3D: 0.7248, Ratio: 0.1647
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 2.7, Modularity F 3D: 0.1117, Modularity 3D: 0.7248, Ratio: 0.1542
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 3.1, Modularity F 3D: 0.1153, Modularity 3D: 0.7248, Ratio: 0.1591
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 3.5, Modularity F 3D: 0.1154, Modularity 3D: 0.7248, Ratio: 0.1593
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 3.8, Modularity F 3D: 0.1063, Modularity 3D: 0.7248, Ratio: 0.1467
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 4.2, Modularity F 3D: 0.1190, Modularity 3D: 0.7248, Ratio: 0.1642
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 4.6, Modularity F 3D: 0.1114, Modularity 3D: 0.7248, Ratio: 0.1537
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 4.9, Modularity F 3D: 0.1115, Modularity 3D: 0.7248, Ratio: 0.1539
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 5.3, Modularity F 3D: 0.0884, Modularity 3D: 0.7248, Ratio: 0.1219
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 5.7, Modularity F 3D: 0.0783, Modularity 3D: 0.7248, Ratio: 0.1080
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 6.0, Modularity F 3D: 0.0934, Modularity 3D: 0.7248, Ratio: 0.1289
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 6.4, Modularity F 3D: 0.0857, Modularity 3D: 0.7248, Ratio: 0.1183
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 6.8, Modularity F 3D: 0.0692, Modularity 3D: 0.7248, Ratio: 0.0954
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 7.1, Modularity F 3D: 0.0711, Modularity 3D: 0.7248, Ratio: 0.0981
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 7.5, Modularity F 3D: 0.0727, Modularity 3D: 0.7248, Ratio: 0.1003
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 7.9, Modularity F 3D: 0.0814, Modularity 3D: 0.7248, Ratio: 0.1124
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 8.2, Modularity F 3D: 0.1150, Modularity 3D: 0.7248, Ratio: 0.1587
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 8.6, Modularity F 3D: 0.1461, Modularity 3D: 0.7248, Ratio: 0.2016
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 9.0, Modularity F 3D: 0.2304, Modularity 3D: 0.7248, Ratio: 0.3179
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 9.3, Modularity F 3D: 0.1729, Modularity 3D: 0.7248, Ratio: 0.2386
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 9.7, Modularity F 3D: 0.1280, Modularity 3D: 0.7248, Ratio: 0.1766
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 10.1, Modularity F 3D: 0.2409, Modularity 3D: 0.7248, Ratio: 0.3324
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 10.4, Modularity F 3D: 0.3203, Modularity 3D: 0.7248, Ratio: 0.4419
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 10.8, Modularity F 3D: 0.2524, Modularity 3D: 0.7248, Ratio: 0.3482
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 11.2, Modularity F 3D: 0.2856, Modularity 3D: 0.7248, Ratio: 0.3940
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 11.6, Modularity F 3D: 0.3960, Modularity 3D: 0.7248, Ratio: 0.5464
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 11.9, Modularity F 3D: 0.3446, Modularity 3D: 0.7248, Ratio: 0.4754
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 12.3, Modularity F 3D: 0.3587, Modularity 3D: 0.7248, Ratio: 0.4949
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 12.7, Modularity F 3D: 0.4401, Modularity 3D: 0.7248, Ratio: 0.6072
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 13.0, Modularity F 3D: 0.3813, Modularity 3D: 0.7248, Ratio: 0.5262
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 13.4, Modularity F 3D: 0.4486, Modularity 3D: 0.7248, Ratio: 0.6189
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 13.8, Modularity F 3D: 0.4157, Modularity 3D: 0.7248, Ratio: 0.5735
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 14.1, Modularity F 3D: 0.3858, Modularity 3D: 0.7248, Ratio: 0.5323
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 14.5, Modularity F 3D: 0.4203, Modularity 3D: 0.7248, Ratio: 0.5799
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 14.9, Modularity F 3D: 0.4594, Modularity 3D: 0.7248, Ratio: 0.6339
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 15.2, Modularity F 3D: 0.4002, Modularity 3D: 0.7248, Ratio: 0.5521
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 15.6, Modularity F 3D: 0.4038, Modularity 3D: 0.7248, Ratio: 0.5571
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 16.0, Modularity F 3D: 0.4241, Modularity 3D: 0.7248, Ratio: 0.5851
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 16.3, Modularity F 3D: 0.4134, Modularity 3D: 0.7248, Ratio: 0.5704
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 16.7, Modularity F 3D: 0.4362, Modularity 3D: 0.7248, Ratio: 0.6018
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 17.1, Modularity F 3D: 0.4581, Modularity 3D: 0.7248, Ratio: 0.6321
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 17.4, Modularity F 3D: 0.5296, Modularity 3D: 0.7248, Ratio: 0.7307
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 17.8, Modularity F 3D: 0.4433, Modularity 3D: 0.7248, Ratio: 0.6116
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 18.2, Modularity F 3D: 0.4443, Modularity 3D: 0.7248, Ratio: 0.6131
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 18.5, Modularity F 3D: 0.4962, Modularity 3D: 0.7248, Ratio: 0.6847
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 18.9, Modularity F 3D: 0.4445, Modularity 3D: 0.7248, Ratio: 0.6133
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 19.3, Modularity F 3D: 0.4123, Modularity 3D: 0.7248, Ratio: 0.5688
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 19.6, Modularity F 3D: 0.4959, Modularity 3D: 0.7248, Ratio: 0.6843
# Sigma: 0.0642, Gini: 0.7578, Exc Weight: 20.0, Modularity F 3D: 0.5288, Modularity 3D: 0.7248, Ratio: 0.7296
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 2.0, Modularity F 3D: 0.1155, Modularity 3D: 0.7237, Ratio: 0.1596
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 2.4, Modularity F 3D: 0.1137, Modularity 3D: 0.7237, Ratio: 0.1571
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 2.7, Modularity F 3D: 0.1190, Modularity 3D: 0.7237, Ratio: 0.1645
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 3.1, Modularity F 3D: 0.1206, Modularity 3D: 0.7237, Ratio: 0.1666
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 3.5, Modularity F 3D: 0.1184, Modularity 3D: 0.7237, Ratio: 0.1636
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 3.8, Modularity F 3D: 0.1185, Modularity 3D: 0.7237, Ratio: 0.1638
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 4.2, Modularity F 3D: 0.1189, Modularity 3D: 0.7237, Ratio: 0.1643
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 4.6, Modularity F 3D: 0.1140, Modularity 3D: 0.7237, Ratio: 0.1576
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 4.9, Modularity F 3D: 0.1133, Modularity 3D: 0.7237, Ratio: 0.1565
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 5.3, Modularity F 3D: 0.1017, Modularity 3D: 0.7237, Ratio: 0.1406
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 5.7, Modularity F 3D: 0.0908, Modularity 3D: 0.7237, Ratio: 0.1254
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 6.0, Modularity F 3D: 0.0987, Modularity 3D: 0.7237, Ratio: 0.1364
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 6.4, Modularity F 3D: 0.0778, Modularity 3D: 0.7237, Ratio: 0.1075
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 6.8, Modularity F 3D: 0.0712, Modularity 3D: 0.7237, Ratio: 0.0984
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 7.1, Modularity F 3D: 0.0785, Modularity 3D: 0.7237, Ratio: 0.1085
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 7.5, Modularity F 3D: 0.2194, Modularity 3D: 0.7237, Ratio: 0.3032
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 7.9, Modularity F 3D: 0.1686, Modularity 3D: 0.7237, Ratio: 0.2330
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 8.2, Modularity F 3D: 0.2642, Modularity 3D: 0.7237, Ratio: 0.3651
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 8.6, Modularity F 3D: 0.3776, Modularity 3D: 0.7237, Ratio: 0.5218
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 9.0, Modularity F 3D: 0.2765, Modularity 3D: 0.7237, Ratio: 0.3820
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 9.3, Modularity F 3D: 0.3411, Modularity 3D: 0.7237, Ratio: 0.4713
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 9.7, Modularity F 3D: 0.4322, Modularity 3D: 0.7237, Ratio: 0.5972
# Sigma: 0.0664, Gini: 0.7481, Exc Weight: 10.1, Modularity F 3D: 0.3787, Modularity 3D: 0.7237, Ratio: 0.5233
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[141], line 62
#      59     print(f"Archivo no encontrado para sigma={sigma:.4f}, exc_weight={exc_weight:.1f}")
#      60     continue
# ---> 62 F, F_binary, F_ordered, order, communities = fcn.build_F_matrix(filename_dyn_3D, SIM_TIME = 10000, N = A_3D.shape[0])
#      63 F_binary = ((F_binary + F_binary.T) > 0).astype(int)  # Ensure the functional connectivity matrix is symmetric and binary
#      64 modularity_F_3D = louvain_modularity(F_binary)
#
# File c:\Users\Admin\Desktop\Master\TFM\functions_create_networks.py:1980, in build_F_matrix(filename_dynamics, SIM_TIME, N)
#    1976 F = np.corrcoef(M, rowvar=False)
#    1978 F_binary, threshold = binarize_functional_matrix(F, percentile=90)
# -> 1980 F_ordered, order, communities = order_F_louvain_from_raster(
#    1981     F,
#    1982     F_binary,
#    1983     firings_i,
#    1984     seed=0
#    1985 )
#    1987 return F, F_binary, F_ordered, order, communities
#
# File c:\Users\Admin\Desktop\Master\TFM\functions_create_networks.py:1530, in order_F_louvain_from_raster(F, F_binary, firings_i, seed)
#    1525 inactive = np.setdiff1d(all_neurons, active)
#    1527 # print(f"Neuronas activas: {len(active)}")
#    1528 # print(f"Neuronas inactivas: {len(inactive)}")
# -> 1530 W_active = F_binary[np.ix_(active, active)].copy()
#    1531 np.fill_diagonal(W_active, 0)
#    1533 G = nx.from_numpy_array(W_active)
#
# IndexError: index 5503 is out of bounds for axis 0 with size 5503

# %% [markdown]
# # 3D
